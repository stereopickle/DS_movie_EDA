# %% [markdown]
# # Data Collection
#
# Here we are collecting the appropriate data.
# Since we are interested in virality of the movies, we will get movie data from the Movie Database, which has popularity measures. Then combine it to IMDB movie data and TN budget/revenue data.

# %% [markdown]
# ### The Movie Database (TMDB)
# It's a good open source alternative to IMDB.
# The documentation is here: https://www.themoviedb.org/documentation/api

# %% [markdown]
# #### Load the movie database API

# %%
import numpy as np
import pandas as pd

# %%
# Loading tmdb_api
# You must get your API key from themoviedb.org 
# and save your API key("api_key") in .secret/tmdb_api.json 

import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)

path = '/Users/stereopickles/.secret' # input the location of your tmdb_api.json

api_key = get_keys(f"{path}/tmdb_api.json")['api_key']

# %%
# Collecting basic movie data with popularity and voting

import requests

url = 'https://api.themoviedb.org/3/discover/movie'

url_params = {
    "api_key": api_key,
    "sort_by": "popularity.desc", # sort by popularity
    "page": 1, # each page contains 20 movies
    "release_date.gte": '2000-01-01' 

}

resp = requests.get(url, params = url_params)
print(resp.status_code)
# if prints 200, we are good.
# Out:
# 200

# %%
# Now that we reviewed the data type, 
# I'll run through each pages to create a full dataset 
# of top 10000 popular movies since 2000.

tmdb_dat = []

for i in range(500):
    url_params = {
        "api_key": api_key,
        "sort_by": "popularity.desc",
        "page": i+1,
        "release_date.gte": '2000-01-01' 
        #only movies with release date greater than 2000
    }
    resp = requests.get(url, params = url_params)
    try: 
        tmdb_dat.extend(resp.json()['results'])
    except:
        print(f"Error on page {i+1}")
        
tmdb_dat[0]
# Out:
# {'popularity': 168.221,
#  'vote_count': 3860,
#  'video': False,
#  'poster_path': '/xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg',
#  'id': 419704,
#  'adult': False,
#  'backdrop_path': '/t4z8OlOEzH7J1JRFUN3rcm6XHNL.jpg',
#  'original_language': 'en',
#  'original_title': 'Ad Astra',
#  'genre_ids': [18, 878],
#  'title': 'Ad Astra',
#  'vote_average': 6.1,
#  'overview': 'The near future, a time when both hope and hardships drive humanity to look to the stars and beyond. While a mysterious phenomenon menaces to destroy life on planet Earth, astronaut Roy McBride undertakes a mission across the immensity of space and its many perils to uncover the truth about a lost expedition that decades before boldly faced emptiness and silence in search of the unknown.',
#  'release_date': '2019-09-17'}

# %%
movie_df = pd.DataFrame(tmdb_dat)
print(movie_df.shape)
movie_df.head(2)
# Out:
# (10000, 14)
#    popularity  vote_count  video                       poster_path      id  \
# 0     168.221        3860  False  /xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg  419704
# 1     197.612         104  False  /h1B7tW0t399VDjAcWJh8m87469b.jpg  556574
#
#    adult                     backdrop_path original_language original_title  \
# 0  False  /t4z8OlOEzH7J1JRFUN3rcm6XHNL.jpg                en       Ad Astra
# 1  False  /uWVkEo9PWHu9algZsiLPi6sRU64.jpg                en       Hamilton
#
#    genre_ids     title  vote_average  \
# 0  [18, 878]  Ad Astra           6.1
# 1   [18, 36]  Hamilton           8.7
#
#                                             overview release_date
# 0  The near future, a time when both hope and har...   2019-09-17
# 1  Presenting the tale of American founding fathe...   2020-07-03

# %%
# seems like some movies made before 2000 got in. Let's remove it.
movie_df = movie_df[movie_df.release_date >= '2000-01-01']

# %% [markdown]
# #### Additional cleaning
# Since our dataframe is getting bigger, and it contains some information we will not be looking at, let's remove those columns.

# %%
movie_df.drop(['video', 'poster_path','backdrop_path', 'original_title', 'genre_ids'], 
              axis = 1, inplace = True)

# %%
movie_df.head(2)
# Out:
#    popularity  vote_count      id  adult original_language     title  \
# 0     168.221        3860  419704  False                en  Ad Astra
# 1     197.612         104  556574  False                en  Hamilton
#
#    vote_average                                           overview  \
# 0           6.1  The near future, a time when both hope and har...
# 1           8.7  Presenting the tale of American founding fathe...
#
#   release_date
# 0   2019-09-17
# 1   2020-07-03

# %% [markdown]
# ### Adding more information
#
# Additionally, our questions need information on casting, budget, revenues, MPAA, etc.
# We need to get MPAA ratings for US, fetching separtely from TMDB.

# %% [markdown]
# #### MPAA Rating
# Lastly, I would like MPAA Rating. This is in the release_dates not called in the main movie tables.

# %%
movie_df = movie_df.sort_values('id')

# %%
# reviewing MPAA data

url = f'https://api.themoviedb.org/3/movie/{movie_df.id[10]}/release_dates'

url_params = {
    "api_key": api_key
}

resp = requests.get(url, params = url_params)
print(resp.status_code)
# Out:
# 200

# %%
# get information from each movie in movie_df (This will take a while)
MPAA = {}

for ind in movie_df.id:
    url = f'https://api.themoviedb.org/3/movie/{ind}/release_dates'
    url_params = {
        "api_key": api_key
    }
    resp = requests.get(url, params = url_params)
    res = resp.json()['results']
    try:
        MPAA[ind] = [x for x in res if x['iso_3166_1'] == 'US'][0]['release_dates'][0]['certification']
    except: 
        print(f"error on {ind}: {([x for x in res if x['iso_3166_1'] == 'US'])}")
        MPAA[ind] = np.nan
              
    print(f"{ind} complete / {movie_df.id[-1]}")
# Out:
# 12 complete / 6303
# 16 complete / 6303
# 20 complete / 6303
# 22 complete / 6303
# 24 complete / 6303
# 25 complete / 6303
# 27 complete / 6303
# 35 complete / 6303
# 38 complete / 6303
# 55 complete / 6303
# 58 complete / 6303
# 59 complete / 6303
# 64 complete / 6303
# 65 complete / 6303
# 69 complete / 6303
# 70 complete / 6303
# 71 complete / 6303
# 74 complete / 6303
# 77 complete / 6303
# 79 complete / 6303
# 80 complete / 6303
# 82 complete / 6303
# 83 complete / 6303
# 86 complete / 6303
# 98 complete / 6303
# 107 complete / 6303
# error on 113: []
# 113 complete / 6303
# 116 complete / 6303
# 118 complete / 6303
# 120 complete / 6303
# 121 complete / 6303
# 122 complete / 6303
# 129 complete / 6303
# 134 complete / 6303
# 141 complete / 6303
# 142 complete / 6303
# 146 complete / 6303
# 148 complete / 6303
# 153 complete / 6303
# 155 complete / 6303
# 161 complete / 6303
# 163 complete / 6303
# 167 complete / 6303
# 170 complete / 6303
# 176 complete / 6303
# 179 complete / 6303
# 180 complete / 6303
# 182 complete / 6303
# 186 complete / 6303
# 187 complete / 6303
# 189 complete / 6303
# 194 complete / 6303
# 201 complete / 6303
# 205 complete / 6303
# 214 complete / 6303
# 215 complete / 6303
# 217 complete / 6303
# 219 complete / 6303
# 231 complete / 6303
# 237 complete / 6303
# 243 complete / 6303
# 245 complete / 6303
# 246 complete / 6303
# 254 complete / 6303
# 257 complete / 6303
# 272 complete / 6303
# 277 complete / 6303
# 285 complete / 6303
# 292 complete / 6303
# 296 complete / 6303
# 298 complete / 6303
# 300 complete / 6303
# 302 complete / 6303
# 308 complete / 6303
# 310 complete / 6303
# 314 complete / 6303
# 318 complete / 6303
# 320 complete / 6303
# 322 complete / 6303
# 326 complete / 6303
# 338 complete / 6303
# 350 complete / 6303
# 363 complete / 6303
# 388 complete / 6303
# 392 complete / 6303
# 393 complete / 6303
# 395 complete / 6303
# 398 complete / 6303
# 401 complete / 6303
# 411 complete / 6303
# 421 complete / 6303
# 423 complete / 6303
# 425 complete / 6303
# 435 complete / 6303
# 437 complete / 6303
# 438 complete / 6303
# 440 complete / 6303
# 441 complete / 6303
# 445 complete / 6303
# 453 complete / 6303
# 455 complete / 6303
# 462 complete / 6303
# 467 complete / 6303
# 470 complete / 6303
# 479 complete / 6303
# 480 complete / 6303
# 496 complete / 6303
# 501 complete / 6303
# 503 complete / 6303
# 504 complete / 6303
# 508 complete / 6303
# 512 complete / 6303
# 533 complete / 6303
# 534 complete / 6303
# 540 complete / 6303
# 553 complete / 6303
# 557 complete / 6303
# 558 complete / 6303
# 559 complete / 6303
# 561 complete / 6303
# 565 complete / 6303
# error on 572: []
# 572 complete / 6303
# 575 complete / 6303
# 582 complete / 6303
# 585 complete / 6303
# 587 complete / 6303
# 588 complete / 6303
# 590 complete / 6303
# 591 complete / 6303
# 594 complete / 6303
# 598 complete / 6303
# 604 complete / 6303
# 605 complete / 6303
# 608 complete / 6303
# 612 complete / 6303
# 613 complete / 6303
# 615 complete / 6303
# 616 complete / 6303
# 634 complete / 6303
# 640 complete / 6303
# 641 complete / 6303
# 644 complete / 6303
# 647 complete / 6303
# 652 complete / 6303
# 663 complete / 6303
# 670 complete / 6303
# 671 complete / 6303
# 672 complete / 6303
# 673 complete / 6303
# 674 complete / 6303
# 675 complete / 6303
# 676 complete / 6303
# 693 complete / 6303
# 711 complete / 6303
# 747 complete / 6303
# 752 complete / 6303
# 767 complete / 6303
# 768 complete / 6303
# 773 complete / 6303
# 786 complete / 6303
# 787 complete / 6303
# 791 complete / 6303
# 806 complete / 6303
# 808 complete / 6303
# 809 complete / 6303
# 810 complete / 6303
# 818 complete / 6303
# 824 complete / 6303
# 834 complete / 6303
# 842 complete / 6303
# 843 complete / 6303
# 844 complete / 6303
# 853 complete / 6303
# 855 complete / 6303
# 866 complete / 6303
# 868 complete / 6303
# 869 complete / 6303
# 883 complete / 6303
# 889 complete / 6303
# 920 complete / 6303
# 921 complete / 6303
# 924 complete / 6303
# 950 complete / 6303
# 953 complete / 6303
# 955 complete / 6303
# 956 complete / 6303
# 979 complete / 6303
# 1018 complete / 6303
# 1023 complete / 6303
# 1116 complete / 6303
# 1124 complete / 6303
# 1125 complete / 6303
# 1164 complete / 6303
# 1165 complete / 6303
# 1246 complete / 6303
# 1247 complete / 6303
# 1249 complete / 6303
# 1250 complete / 6303
# 1251 complete / 6303
# 1252 complete / 6303
# 1253 complete / 6303
# 1255 complete / 6303
# 1257 complete / 6303
# 1259 complete / 6303
# 1262 complete / 6303
# 1265 complete / 6303
# 1266 complete / 6303
# 1267 complete / 6303
# 1268 complete / 6303
# 1271 complete / 6303
# 1272 complete / 6303
# 1273 complete / 6303
# 1278 complete / 6303
# error on 1280: []
# 1280 complete / 6303
# 1282 complete / 6303
# error on 1284: []
# 1284 complete / 6303
# 1359 complete / 6303
# 1360 complete / 6303
# 1364 complete / 6303
# 1365 complete / 6303
# 1372 complete / 6303
# 1378 complete / 6303
# 1381 complete / 6303
# 1382 complete / 6303
# 1391 complete / 6303
# 1392 complete / 6303
# 1402 complete / 6303
# 1407 complete / 6303
# 1415 complete / 6303
# 1417 complete / 6303
# 1418 complete / 6303
# 1420 complete / 6303
# 1422 complete / 6303
# 1427 complete / 6303
# 1428 complete / 6303
# 1429 complete / 6303
# 1430 complete / 6303
# 1433 complete / 6303
# 1440 complete / 6303
# 1441 complete / 6303
# 1444 complete / 6303
# 1452 complete / 6303
# 1487 complete / 6303
# 1491 complete / 6303
# 1493 complete / 6303
# 1494 complete / 6303
# 1495 complete / 6303
# 1523 complete / 6303
# 1534 complete / 6303
# 1535 complete / 6303
# 1537 complete / 6303
# 1538 complete / 6303
# 1544 complete / 6303
# 1546 complete / 6303
# 1550 complete / 6303
# 1553 complete / 6303
# error on 1555: []
# 1555 complete / 6303
# 1562 complete / 6303
# 1571 complete / 6303
# 1574 complete / 6303
# 1576 complete / 6303
# 1577 complete / 6303
# 1579 complete / 6303
# 1581 complete / 6303
# 1584 complete / 6303
# 1586 complete / 6303
# 1588 complete / 6303
# 1593 complete / 6303
# 1597 complete / 6303
# 1599 complete / 6303
# 1609 complete / 6303
# 1613 complete / 6303
# 1619 complete / 6303
# 1620 complete / 6303
# 1635 complete / 6303
# 1636 complete / 6303
# 1640 complete / 6303
# 1646 complete / 6303
# 1647 complete / 6303
# 1653 complete / 6303
# 1656 complete / 6303
# 1665 complete / 6303
# 1666 complete / 6303
# 1667 complete / 6303
# 1677 complete / 6303
# 1683 complete / 6303
# 1690 complete / 6303
# 1691 complete / 6303
# 1696 complete / 6303
# 1698 complete / 6303
# 1717 complete / 6303
# 1722 complete / 6303
# 1724 complete / 6303
# 1726 complete / 6303
# 1729 complete / 6303
# 1730 complete / 6303
# 1734 complete / 6303
# 1735 complete / 6303
# 1738 complete / 6303
# 1771 complete / 6303
# 1777 complete / 6303
# 1781 complete / 6303
# 1783 complete / 6303
# 1791 complete / 6303
# 1792 complete / 6303
# 1807 complete / 6303
# 1809 complete / 6303
# 1817 complete / 6303
# 1819 complete / 6303
# 1824 complete / 6303
# error on 1826: []
# 1826 complete / 6303
# 1830 complete / 6303
# 1833 complete / 6303
# 1845 complete / 6303
# 1852 complete / 6303
# 1865 complete / 6303
# 1872 complete / 6303
# 1887 complete / 6303
# 1894 complete / 6303
# 1895 complete / 6303
# 1900 complete / 6303
# 1901 complete / 6303
# 1903 complete / 6303
# 1904 complete / 6303
# 1907 complete / 6303
# 1919 complete / 6303
# 1921 complete / 6303
# 1927 complete / 6303
# 1930 complete / 6303
# 1931 complete / 6303
# 1933 complete / 6303
# 1944 complete / 6303
# 1947 complete / 6303
# 1948 complete / 6303
# 1949 complete / 6303
# 1950 complete / 6303
# 1951 complete / 6303
# 1954 complete / 6303
# 1957 complete / 6303
# 1961 complete / 6303
# 1966 complete / 6303
# 1969 complete / 6303
# 1970 complete / 6303
# 1975 complete / 6303
# 1977 complete / 6303
# 1979 complete / 6303
# 1985 complete / 6303
# 1988 complete / 6303
# error on 1989: []
# 1989 complete / 6303
# 1991 complete / 6303
# 1992 complete / 6303
# 1995 complete / 6303
# 1996 complete / 6303
# 1997 complete / 6303
# 1999 complete / 6303
# 2001 complete / 6303
# 2003 complete / 6303
# 2009 complete / 6303
# error on 2013: []
# 2013 complete / 6303
# 2014 complete / 6303
# 2017 complete / 6303
# 2018 complete / 6303
# 2022 complete / 6303
# 2023 complete / 6303
# 2024 complete / 6303
# 2026 complete / 6303
# 2034 complete / 6303
# 2043 complete / 6303
# 2044 complete / 6303
# 2046 complete / 6303
# 2048 complete / 6303
# 2055 complete / 6303
# 2056 complete / 6303
# 2057 complete / 6303
# 2059 complete / 6303
# 2062 complete / 6303
# 2067 complete / 6303
# 2069 complete / 6303
# 2082 complete / 6303
# 2084 complete / 6303
# 2085 complete / 6303
# 2100 complete / 6303
# 2103 complete / 6303
# 2110 complete / 6303
# 2114 complete / 6303
# 2116 complete / 6303
# 2122 complete / 6303
# 2123 complete / 6303
# 2133 complete / 6303
# 2135 complete / 6303
# 2140 complete / 6303
# 2144 complete / 6303
# 2155 complete / 6303
# 2165 complete / 6303
# 2176 complete / 6303
# 2179 complete / 6303
# 2185 complete / 6303
# 2196 complete / 6303
# 2207 complete / 6303
# 2239 complete / 6303
# 2251 complete / 6303
# 2252 complete / 6303
# 2253 complete / 6303
# 2260 complete / 6303
# 2266 complete / 6303
# 2267 complete / 6303
# 2268 complete / 6303
# 2269 complete / 6303
# 2270 complete / 6303
# 2274 complete / 6303
# 2284 complete / 6303
# 2288 complete / 6303
# 2289 complete / 6303
# 2294 complete / 6303
# 2295 complete / 6303
# 2309 complete / 6303
# 2310 complete / 6303
# 2312 complete / 6303
# 2313 complete / 6303
# 2332 complete / 6303
# 2334 complete / 6303
# 2335 complete / 6303
# 2355 complete / 6303
# 2359 complete / 6303
# 2395 complete / 6303
# error on 2440: []
# 2440 complete / 6303
# 2447 complete / 6303
# 2454 complete / 6303
# 2486 complete / 6303
# 2501 complete / 6303
# 2502 complete / 6303
# 2503 complete / 6303
# error on 2517: []
# 2517 complete / 6303
# 2539 complete / 6303
# 2567 complete / 6303
# 2577 complete / 6303
# 2610 complete / 6303
# 2637 complete / 6303
# 2642 complete / 6303
# 2652 complete / 6303
# 2655 complete / 6303
# 2662 complete / 6303
# 2675 complete / 6303
# 2698 complete / 6303
# 2728 complete / 6303
# 2749 complete / 6303
# 2750 complete / 6303
# 2752 complete / 6303
# 2755 complete / 6303
# 2757 complete / 6303
# 2770 complete / 6303
# 2771 complete / 6303
# 2779 complete / 6303
# 2787 complete / 6303
# 2789 complete / 6303
# 2800 complete / 6303
# 2830 complete / 6303
# 2832 complete / 6303
# 2841 complete / 6303
# 2882 complete / 6303
# 2899 complete / 6303
# 2959 complete / 6303
# 2976 complete / 6303
# 2977 complete / 6303
# 3021 complete / 6303
# 3040 complete / 6303
# 3093 complete / 6303
# 3131 complete / 6303
# 3132 complete / 6303
# 3134 complete / 6303
# 3172 complete / 6303
# 3176 complete / 6303
# 3291 complete / 6303
# 3432 complete / 6303
# 3472 complete / 6303
# 3489 complete / 6303
# 3509 complete / 6303
# 3536 complete / 6303
# 3563 complete / 6303
# 3580 complete / 6303
# 3594 complete / 6303
# 3602 complete / 6303
# 3603 complete / 6303
# 3635 complete / 6303
# 3638 complete / 6303
# 3683 complete / 6303
# 3716 complete / 6303
# 3902 complete / 6303
# 3933 complete / 6303
# 3981 complete / 6303
# 3989 complete / 6303
# 4012 complete / 6303
# 4108 complete / 6303
# 4133 complete / 6303
# 4141 complete / 6303
# 4147 complete / 6303
# 4148 complete / 6303
# 4169 complete / 6303
# 4170 complete / 6303
# 4226 complete / 6303
# 4234 complete / 6303
# 4244 complete / 6303
# 4247 complete / 6303
# 4248 complete / 6303
# 4251 complete / 6303
# 4256 complete / 6303
# 4257 complete / 6303
# 4258 complete / 6303
# 4283 complete / 6303
# 4327 complete / 6303
# 4347 complete / 6303
# 4348 complete / 6303
# 4349 complete / 6303
# 4351 complete / 6303
# 4379 complete / 6303
# 4380 complete / 6303
# 4413 complete / 6303
# 4442 complete / 6303
# 4464 complete / 6303
# 4474 complete / 6303
# 4475 complete / 6303
# 4512 complete / 6303
# 4513 complete / 6303
# 4515 complete / 6303
# 4517 complete / 6303
# 4523 complete / 6303
# 4538 complete / 6303
# 4547 complete / 6303
# 4550 complete / 6303
# 4551 complete / 6303
# error on 4552: []
# 4552 complete / 6303
# 4553 complete / 6303
# 4564 complete / 6303
# 4566 complete / 6303
# 4588 complete / 6303
# 4597 complete / 6303
# 4599 complete / 6303
# 4614 complete / 6303
# 4629 complete / 6303
# 4638 complete / 6303
# 4641 complete / 6303
# 4643 complete / 6303
# 4658 complete / 6303
# 4688 complete / 6303
# 4689 complete / 6303
# 4723 complete / 6303
# 4771 complete / 6303
# 4787 complete / 6303
# 4836 complete / 6303
# 4858 complete / 6303
# 4911 complete / 6303
# 4912 complete / 6303
# 4922 complete / 6303
# 4935 complete / 6303
# 4942 complete / 6303
# 4944 complete / 6303
# 4953 complete / 6303
# 4958 complete / 6303
# 4959 complete / 6303
# 4960 complete / 6303
# 4964 complete / 6303
# 4965 complete / 6303
# 4967 complete / 6303
# 4970 complete / 6303
# 4977 complete / 6303
# 4982 complete / 6303
# 4997 complete / 6303
# 5001 complete / 6303
# 5038 complete / 6303
# 5072 complete / 6303
# 5123 complete / 6303
# 5137 complete / 6303
# 5146 complete / 6303
# 5172 complete / 6303
# 5174 complete / 6303
# 5175 complete / 6303
# 5176 complete / 6303
# error on 5206: []
# 5206 complete / 6303
# 5236 complete / 6303
# 5255 complete / 6303
# 5279 complete / 6303
# 5289 complete / 6303
# 5353 complete / 6303
# 5375 complete / 6303
# 5393 complete / 6303
# 5458 complete / 6303
# 5460 complete / 6303
# 5471 complete / 6303
# 5491 complete / 6303
# 5493 complete / 6303
# 5516 complete / 6303
# 5528 complete / 6303
# 5551 complete / 6303
# 5559 complete / 6303
# 5653 complete / 6303
# 5708 complete / 6303
# 5718 complete / 6303
# 5723 complete / 6303
# 5820 complete / 6303
# 5833 complete / 6303
# 5851 complete / 6303
# 5852 complete / 6303
# 5857 complete / 6303
# 5876 complete / 6303
# 5915 complete / 6303
# 5951 complete / 6303
# 5956 complete / 6303
# 5966 complete / 6303
# 5994 complete / 6303
# 6020 complete / 6303
# 6022 complete / 6303
# 6023 complete / 6303
# 6038 complete / 6303
# 6073 complete / 6303
# 6076 complete / 6303
# 6145 complete / 6303
# 6171 complete / 6303
# 6278 complete / 6303
# 6282 complete / 6303
# error on 6309: []
# 6309 complete / 6303
# 6312 complete / 6303
# 6418 complete / 6303
# 6439 complete / 6303
# 6440 complete / 6303
# 6466 complete / 6303
# 6473 complete / 6303
# 6477 complete / 6303
# 6478 complete / 6303
# 6479 complete / 6303
# 6519 complete / 6303
# 6521 complete / 6303
# 6537 complete / 6303
# 6538 complete / 6303
# 6557 complete / 6303
# 6575 complete / 6303
# 6589 complete / 6303
# 6615 complete / 6303
# 6637 complete / 6303
# 6639 complete / 6303
# 6687 complete / 6303
# 6795 complete / 6303
# 6877 complete / 6303
# 6933 complete / 6303
# 6935 complete / 6303
# 6947 complete / 6303
# 6957 complete / 6303
# 6961 complete / 6303
# 6963 complete / 6303
# 6964 complete / 6303
# 6968 complete / 6303
# 6972 complete / 6303
# 6973 complete / 6303
# 6977 complete / 6303
# 7006 complete / 6303
# 7090 complete / 6303
# 7092 complete / 6303
# 7093 complete / 6303
# 7131 complete / 6303
# 7182 complete / 6303
# 7183 complete / 6303
# 7191 complete / 6303
# 7211 complete / 6303
# 7214 complete / 6303
# 7220 complete / 6303
# 7229 complete / 6303
# 7233 complete / 6303
# 7249 complete / 6303
# 7278 complete / 6303
# error on 7281: []
# 7281 complete / 6303
# 7288 complete / 6303
# 7291 complete / 6303
# 7299 complete / 6303
# 7303 complete / 6303
# 7304 complete / 6303
# 7326 complete / 6303
# 7342 complete / 6303
# 7345 complete / 6303
# 7347 complete / 6303
# 7350 complete / 6303
# 7353 complete / 6303
# 7364 complete / 6303
# 7443 complete / 6303
# 7445 complete / 6303
# 7446 complete / 6303
# 7450 complete / 6303
# 7451 complete / 6303
# 7453 complete / 6303
# 7457 complete / 6303
# 7459 complete / 6303
# 7461 complete / 6303
# 7484 complete / 6303
# 7485 complete / 6303
# 7501 complete / 6303
# 7508 complete / 6303
# 7510 complete / 6303
# 7511 complete / 6303
# 7512 complete / 6303
# 7515 complete / 6303
# 7516 complete / 6303
# 7518 complete / 6303
# 7548 complete / 6303
# 7549 complete / 6303
# 7551 complete / 6303
# 7552 complete / 6303
# 7553 complete / 6303
# 7555 complete / 6303
# error on 7735: []
# 7735 complete / 6303
# 7839 complete / 6303
# 7840 complete / 6303
# 7859 complete / 6303
# 7861 complete / 6303
# 7862 complete / 6303
# 7870 complete / 6303
# 7872 complete / 6303
# 7873 complete / 6303
# 7874 complete / 6303
# 7913 complete / 6303
# 7916 complete / 6303
# 7942 complete / 6303
# 7944 complete / 6303
# 7972 complete / 6303
# 7978 complete / 6303
# 7980 complete / 6303
# 7985 complete / 6303
# 8007 complete / 6303
# 8046 complete / 6303
# 8051 complete / 6303
# 8053 complete / 6303
# 8054 complete / 6303
# 8055 complete / 6303
# 8060 complete / 6303
# 8065 complete / 6303
# 8066 complete / 6303
# 8080 complete / 6303
# 8090 complete / 6303
# 8094 complete / 6303
# 8141 complete / 6303
# 8193 complete / 6303
# 8194 complete / 6303
# 8202 complete / 6303
# 8204 complete / 6303
# 8247 complete / 6303
# 8265 complete / 6303
# 8270 complete / 6303
# 8271 complete / 6303
# 8272 complete / 6303
# 8273 complete / 6303
# 8274 complete / 6303
# 8275 complete / 6303
# 8277 complete / 6303
# 8284 complete / 6303
# 8285 complete / 6303
# 8292 complete / 6303
# 8316 complete / 6303
# 8319 complete / 6303
# 8321 complete / 6303
# 8324 complete / 6303
# 8326 complete / 6303
# 8328 complete / 6303
# 8329 complete / 6303
# 8338 complete / 6303
# 8346 complete / 6303
# 8355 complete / 6303
# 8358 complete / 6303
# 8359 complete / 6303
# 8363 complete / 6303
# error on 8366: []
# 8366 complete / 6303
# 8386 complete / 6303
# 8390 complete / 6303
# 8398 complete / 6303
# 8409 complete / 6303
# 8414 complete / 6303
# 8427 complete / 6303
# 8435 complete / 6303
# 8452 complete / 6303
# 8453 complete / 6303
# 8456 complete / 6303
# 8457 complete / 6303
# 8461 complete / 6303
# 8470 complete / 6303
# 8488 complete / 6303
# 8489 complete / 6303
# 8555 complete / 6303
# 8584 complete / 6303
# 8617 complete / 6303
# 8618 complete / 6303
# 8619 complete / 6303
# 8643 complete / 6303
# 8645 complete / 6303
# error on 8653: []
# 8653 complete / 6303
# 8665 complete / 6303
# 8669 complete / 6303
# 8676 complete / 6303
# 8681 complete / 6303
# 8696 complete / 6303
# 8698 complete / 6303
# 8699 complete / 6303
# 8780 complete / 6303
# 8814 complete / 6303
# 8832 complete / 6303
# 8835 complete / 6303
# 8836 complete / 6303
# 8843 complete / 6303
# 8848 complete / 6303
# 8849 complete / 6303
# 8859 complete / 6303
# 8869 complete / 6303
# 8870 complete / 6303
# 8871 complete / 6303
# 8880 complete / 6303
# 8881 complete / 6303
# 8884 complete / 6303
# 8885 complete / 6303
# 8909 complete / 6303
# 8915 complete / 6303
# 8920 complete / 6303
# 8922 complete / 6303
# 8923 complete / 6303
# error on 8937: []
# 8937 complete / 6303
# 8938 complete / 6303
# 8940 complete / 6303
# 8942 complete / 6303
# 8944 complete / 6303
# 8952 complete / 6303
# 8953 complete / 6303
# 8954 complete / 6303
# 8960 complete / 6303
# 8961 complete / 6303
# 8965 complete / 6303
# 8966 complete / 6303
# 8967 complete / 6303
# 8968 complete / 6303
# 8975 complete / 6303
# 8976 complete / 6303
# 8978 complete / 6303
# 8981 complete / 6303
# 8982 complete / 6303
# 8988 complete / 6303
# 8991 complete / 6303
# 8997 complete / 6303
# 8998 complete / 6303
# 8999 complete / 6303
# 9005 complete / 6303
# 9007 complete / 6303
# 9009 complete / 6303
# 9011 complete / 6303
# 9012 complete / 6303
# 9016 complete / 6303
# 9017 complete / 6303
# 9021 complete / 6303
# 9022 complete / 6303
# 9023 complete / 6303
# 9026 complete / 6303
# 9027 complete / 6303
# 9029 complete / 6303
# 9030 complete / 6303
# 9034 complete / 6303
# 9035 complete / 6303
# 9036 complete / 6303
# 9038 complete / 6303
# 9039 complete / 6303
# 9042 complete / 6303
# 9043 complete / 6303
# 9044 complete / 6303
# 9053 complete / 6303
# 9072 complete / 6303
# 9074 complete / 6303
# 9075 complete / 6303
# 9081 complete / 6303
# 9093 complete / 6303
# 9104 complete / 6303
# error on 9256: []
# 9256 complete / 6303
# 9257 complete / 6303
# 9260 complete / 6303
# 9262 complete / 6303
# 9266 complete / 6303
# 9270 complete / 6303
# 9275 complete / 6303
# 9280 complete / 6303
# 9282 complete / 6303
# 9285 complete / 6303
# 9286 complete / 6303
# 9290 complete / 6303
# 9291 complete / 6303
# 9293 complete / 6303
# 9296 complete / 6303
# 9297 complete / 6303
# 9298 complete / 6303
# 9310 complete / 6303
# 9315 complete / 6303
# 9316 complete / 6303
# 9334 complete / 6303
# 9335 complete / 6303
# 9339 complete / 6303
# 9341 complete / 6303
# 9352 complete / 6303
# 9353 complete / 6303
# 9357 complete / 6303
# 9358 complete / 6303
# 9372 complete / 6303
# 9373 complete / 6303
# 9378 complete / 6303
# 9381 complete / 6303
# 9383 complete / 6303
# 9384 complete / 6303
# 9388 complete / 6303
# 9389 complete / 6303
# 9392 complete / 6303
# 9397 complete / 6303
# 9398 complete / 6303
# 9408 complete / 6303
# 9428 complete / 6303
# 9456 complete / 6303
# 9470 complete / 6303
# 9471 complete / 6303
# 9472 complete / 6303
# 9476 complete / 6303
# 9477 complete / 6303
# 9480 complete / 6303
# 9486 complete / 6303
# 9488 complete / 6303
# 9499 complete / 6303
# 9502 complete / 6303
# 9506 complete / 6303
# 9509 complete / 6303
# 9511 complete / 6303
# 9513 complete / 6303
# 9515 complete / 6303
# 9517 complete / 6303
# 9519 complete / 6303
# 9522 complete / 6303
# 9526 complete / 6303
# 9528 complete / 6303
# 9530 complete / 6303
# 9532 complete / 6303
# 9534 complete / 6303
# 9539 complete / 6303
# 9541 complete / 6303
# 9543 complete / 6303
# 9544 complete / 6303
# 9550 complete / 6303
# 9555 complete / 6303
# 9557 complete / 6303
# 9562 complete / 6303
# 9567 complete / 6303
# 9573 complete / 6303
# 9582 complete / 6303
# 9592 complete / 6303
# 9597 complete / 6303
# 9600 complete / 6303
# 9606 complete / 6303
# 9613 complete / 6303
# 9616 complete / 6303
# 9620 complete / 6303
# 9621 complete / 6303
# 9637 complete / 6303
# 9641 complete / 6303
# 9642 complete / 6303
# 9645 complete / 6303
# 9654 complete / 6303
# 9655 complete / 6303
# 9656 complete / 6303
# 9662 complete / 6303
# 9664 complete / 6303
# error on 9666: []
# 9666 complete / 6303
# 9667 complete / 6303
# 9672 complete / 6303
# 9675 complete / 6303
# 9676 complete / 6303
# 9678 complete / 6303
# 9679 complete / 6303
# 9681 complete / 6303
# 9682 complete / 6303
# 9683 complete / 6303
# 9685 complete / 6303
# 9687 complete / 6303
# 9688 complete / 6303
# 9689 complete / 6303
# 9693 complete / 6303
# 9696 complete / 6303
# 9697 complete / 6303
# 9700 complete / 6303
# 9701 complete / 6303
# 9703 complete / 6303
# 9705 complete / 6303
# 9707 complete / 6303
# 9708 complete / 6303
# 9711 complete / 6303
# 9718 complete / 6303
# 9721 complete / 6303
# 9722 complete / 6303
# 9726 complete / 6303
# 9727 complete / 6303
# 9729 complete / 6303
# 9738 complete / 6303
# 9741 complete / 6303
# 9753 complete / 6303
# 9754 complete / 6303
# 9756 complete / 6303
# 9757 complete / 6303
# 9759 complete / 6303
# 9760 complete / 6303
# 9762 complete / 6303
# 9763 complete / 6303
# 9766 complete / 6303
# 9767 complete / 6303
# 9776 complete / 6303
# 9777 complete / 6303
# 9778 complete / 6303
# 9779 complete / 6303
# 9784 complete / 6303
# 9785 complete / 6303
# 9786 complete / 6303
# 9787 complete / 6303
# 9788 complete / 6303
# 9792 complete / 6303
# 9793 complete / 6303
# 9794 complete / 6303
# 9796 complete / 6303
# 9801 complete / 6303
# error on 9803: []
# 9803 complete / 6303
# error on 9805: []
# 9805 complete / 6303
# 9806 complete / 6303
# 9813 complete / 6303
# 9815 complete / 6303
# 9816 complete / 6303
# 9817 complete / 6303
# 9828 complete / 6303
# 9829 complete / 6303
# 9833 complete / 6303
# 9836 complete / 6303
# 9839 complete / 6303
# 9841 complete / 6303
# 9842 complete / 6303
# 9843 complete / 6303
# 9870 complete / 6303
# 9880 complete / 6303
# 9884 complete / 6303
# 9885 complete / 6303
# 9889 complete / 6303
# 9890 complete / 6303
# 9893 complete / 6303
# 9896 complete / 6303
# 9899 complete / 6303
# 9900 complete / 6303
# 9902 complete / 6303
# 9903 complete / 6303
# 9904 complete / 6303
# 9906 complete / 6303
# 9907 complete / 6303
# 9910 complete / 6303
# 9912 complete / 6303
# 9913 complete / 6303
# 9914 complete / 6303
# 9917 complete / 6303
# 9918 complete / 6303
# 9919 complete / 6303
# 9920 complete / 6303
# 9923 complete / 6303
# 9924 complete / 6303
# 9927 complete / 6303
# 9928 complete / 6303
# 9932 complete / 6303
# 9947 complete / 6303
# 9948 complete / 6303
# 9950 complete / 6303
# 9952 complete / 6303
# 9953 complete / 6303
# 9954 complete / 6303
# 9955 complete / 6303
# 9957 complete / 6303
# 9958 complete / 6303
# 9959 complete / 6303
# 9962 complete / 6303
# 9963 complete / 6303
# 9966 complete / 6303
# 9969 complete / 6303
# 9973 complete / 6303
# 9975 complete / 6303
# 9978 complete / 6303
# 9981 complete / 6303
# 9982 complete / 6303
# 9986 complete / 6303
# 9988 complete / 6303
# 9989 complete / 6303
# 9991 complete / 6303
# 9992 complete / 6303
# 10005 complete / 6303
# 10007 complete / 6303
# 10008 complete / 6303
# 10009 complete / 6303
# 10010 complete / 6303
# 10012 complete / 6303
# 10016 complete / 6303
# 10022 complete / 6303
# 10024 complete / 6303
# 10025 complete / 6303
# 10027 complete / 6303
# 10028 complete / 6303
# 10030 complete / 6303
# 10032 complete / 6303
# 10033 complete / 6303
# 10035 complete / 6303
# 10040 complete / 6303
# 10045 complete / 6303
# 10046 complete / 6303
# 10048 complete / 6303
# 10050 complete / 6303
# 10052 complete / 6303
# 10053 complete / 6303
# 10054 complete / 6303
# 10060 complete / 6303
# 10063 complete / 6303
# 10064 complete / 6303
# 10065 complete / 6303
# 10066 complete / 6303
# 10067 complete / 6303
# 10069 complete / 6303
# 10070 complete / 6303
# 10073 complete / 6303
# 10074 complete / 6303
# 10075 complete / 6303
# 10077 complete / 6303
# 10085 complete / 6303
# 10090 complete / 6303
# 10092 complete / 6303
# 10093 complete / 6303
# 10096 complete / 6303
# error on 10103: []
# 10103 complete / 6303
# 10104 complete / 6303
# 10105 complete / 6303
# 10107 complete / 6303
# 10115 complete / 6303
# 10118 complete / 6303
# 10133 complete / 6303
# 10138 complete / 6303
# 10139 complete / 6303
# 10140 complete / 6303
# 10145 complete / 6303
# 10147 complete / 6303
# 10152 complete / 6303
# 10159 complete / 6303
# 10167 complete / 6303
# 10172 complete / 6303
# 10180 complete / 6303
# 10183 complete / 6303
# 10184 complete / 6303
# 10185 complete / 6303
# 10186 complete / 6303
# 10187 complete / 6303
# 10188 complete / 6303
# 10189 complete / 6303
# 10190 complete / 6303
# 10191 complete / 6303
# 10192 complete / 6303
# 10193 complete / 6303
# 10195 complete / 6303
# 10196 complete / 6303
# 10197 complete / 6303
# 10198 complete / 6303
# 10199 complete / 6303
# 10200 complete / 6303
# 10201 complete / 6303
# 10202 complete / 6303
# 10204 complete / 6303
# 10214 complete / 6303
# 10226 complete / 6303
# 10229 complete / 6303
# 10247 complete / 6303
# 10253 complete / 6303
# 10258 complete / 6303
# 10263 complete / 6303
# error on 10268: []
# 10268 complete / 6303
# 10288 complete / 6303
# 10292 complete / 6303
# 10294 complete / 6303
# 10296 complete / 6303
# 10304 complete / 6303
# 10313 complete / 6303
# 10315 complete / 6303
# 10316 complete / 6303
# 10317 complete / 6303
# 10320 complete / 6303
# 10327 complete / 6303
# 10330 complete / 6303
# 10358 complete / 6303
# 10360 complete / 6303
# 10361 complete / 6303
# 10362 complete / 6303
# 10367 complete / 6303
# 10375 complete / 6303
# 10378 complete / 6303
# 10383 complete / 6303
# 10384 complete / 6303
# 10385 complete / 6303
# 10389 complete / 6303
# 10391 complete / 6303
# 10393 complete / 6303
# 10416 complete / 6303
# 10425 complete / 6303
# 10426 complete / 6303
# 10429 complete / 6303
# 10431 complete / 6303
# 10461 complete / 6303
# 10468 complete / 6303
# 10471 complete / 6303
# 10472 complete / 6303
# 10473 complete / 6303
# 10475 complete / 6303
# 10477 complete / 6303
# 10479 complete / 6303
# 10481 complete / 6303
# 10483 complete / 6303
# 10488 complete / 6303
# 10491 complete / 6303
# 10501 complete / 6303
# 10511 complete / 6303
# 10521 complete / 6303
# 10523 complete / 6303
# 10527 complete / 6303
# 10528 complete / 6303
# 10529 complete / 6303
# 10544 complete / 6303
# 10550 complete / 6303
# 10555 complete / 6303
# 10559 complete / 6303
# 10560 complete / 6303
# 10562 complete / 6303
# 10564 complete / 6303
# 10567 complete / 6303
# 10569 complete / 6303
# 10571 complete / 6303
# 10575 complete / 6303
# 10577 complete / 6303
# 10578 complete / 6303
# 10579 complete / 6303
# 10588 complete / 6303
# 10589 complete / 6303
# 10590 complete / 6303
# 10591 complete / 6303
# 10592 complete / 6303
# 10596 complete / 6303
# 10597 complete / 6303
# 10599 complete / 6303
# 10601 complete / 6303
# 10605 complete / 6303
# 10609 complete / 6303
# 10610 complete / 6303
# 10611 complete / 6303
# 10623 complete / 6303
# 10625 complete / 6303
# 10628 complete / 6303
# 10629 complete / 6303
# 10632 complete / 6303
# 10637 complete / 6303
# 10641 complete / 6303
# 10642 complete / 6303
# 10646 complete / 6303
# 10647 complete / 6303
# 10661 complete / 6303
# 10664 complete / 6303
# 10665 complete / 6303
# 10677 complete / 6303
# 10678 complete / 6303
# 10679 complete / 6303
# 10681 complete / 6303
# 10685 complete / 6303
# 10687 complete / 6303
# 10688 complete / 6303
# 10691 complete / 6303
# 10703 complete / 6303
# 10706 complete / 6303
# 10707 complete / 6303
# 10708 complete / 6303
# 10710 complete / 6303
# 10712 complete / 6303
# 10715 complete / 6303
# 10718 complete / 6303
# 10719 complete / 6303
# 10720 complete / 6303
# 10726 complete / 6303
# 10727 complete / 6303
# 10733 complete / 6303
# 10735 complete / 6303
# 10739 complete / 6303
# 10740 complete / 6303
# 10741 complete / 6303
# 10742 complete / 6303
# 10743 complete / 6303
# 10744 complete / 6303
# 10748 complete / 6303
# 10756 complete / 6303
# 10758 complete / 6303
# 10759 complete / 6303
# 10760 complete / 6303
# 10761 complete / 6303
# 10762 complete / 6303
# 10763 complete / 6303
# 10764 complete / 6303
# 10771 complete / 6303
# 10773 complete / 6303
# 10775 complete / 6303
# 10778 complete / 6303
# 10781 complete / 6303
# 10782 complete / 6303
# 10783 complete / 6303
# 10790 complete / 6303
# 10795 complete / 6303
# 10796 complete / 6303
# 10800 complete / 6303
# 10808 complete / 6303
# 10818 complete / 6303
# 10822 complete / 6303
# 10829 complete / 6303
# 10832 complete / 6303
# 10833 complete / 6303
# 10845 complete / 6303
# 10851 complete / 6303
# 10854 complete / 6303
# 10862 complete / 6303
# 10865 complete / 6303
# 10866 complete / 6303
# 10867 complete / 6303
# 10873 complete / 6303
# 10876 complete / 6303
# 10877 complete / 6303
# 10878 complete / 6303
# 10881 complete / 6303
# 10885 complete / 6303
# 10886 complete / 6303
# 10891 complete / 6303
# 10894 complete / 6303
# 10900 complete / 6303
# 10922 complete / 6303
# 10923 complete / 6303
# 10934 complete / 6303
# 10943 complete / 6303
# 10944 complete / 6303
# 10946 complete / 6303
# 10947 complete / 6303
# 10950 complete / 6303
# 10956 complete / 6303
# 10958 complete / 6303
# 10972 complete / 6303
# 10982 complete / 6303
# 10984 complete / 6303
# 10985 complete / 6303
# 10991 complete / 6303
# 10992 complete / 6303
# 10994 complete / 6303
# 10996 complete / 6303
# 11004 complete / 6303
# 11007 complete / 6303
# 11013 complete / 6303
# 11022 complete / 6303
# 11023 complete / 6303
# 11024 complete / 6303
# 11025 complete / 6303
# 11026 complete / 6303
# 11036 complete / 6303
# 11042 complete / 6303
# 11045 complete / 6303
# 11049 complete / 6303
# 11052 complete / 6303
# 11056 complete / 6303
# 11058 complete / 6303
# 11059 complete / 6303
# 11065 complete / 6303
# 11078 complete / 6303
# 11081 complete / 6303
# 11086 complete / 6303
# 11088 complete / 6303
# 11090 complete / 6303
# 11091 complete / 6303
# 11093 complete / 6303
# 11096 complete / 6303
# 11099 complete / 6303
# 11109 complete / 6303
# 11119 complete / 6303
# 11127 complete / 6303
# 11128 complete / 6303
# 11130 complete / 6303
# 11132 complete / 6303
# 11137 complete / 6303
# 11141 complete / 6303
# 11148 complete / 6303
# 11152 complete / 6303
# 11169 complete / 6303
# 11170 complete / 6303
# 11171 complete / 6303
# 11172 complete / 6303
# 11178 complete / 6303
# 11184 complete / 6303
# 11188 complete / 6303
# 11190 complete / 6303
# 11199 complete / 6303
# 11208 complete / 6303
# 11217 complete / 6303
# 11232 complete / 6303
# 11237 complete / 6303
# 11246 complete / 6303
# 11247 complete / 6303
# 11249 complete / 6303
# 11253 complete / 6303
# 11260 complete / 6303
# 11282 complete / 6303
# 11283 complete / 6303
# error on 11297: []
# 11297 complete / 6303
# 11299 complete / 6303
# 11313 complete / 6303
# 11321 complete / 6303
# 11322 complete / 6303
# 11323 complete / 6303
# 11324 complete / 6303
# 11329 complete / 6303
# 11330 complete / 6303
# error on 11344: []
# 11344 complete / 6303
# 11345 complete / 6303
# 11348 complete / 6303
# 11351 complete / 6303
# 11354 complete / 6303
# 11358 complete / 6303
# 11362 complete / 6303
# error on 11366: []
# 11366 complete / 6303
# 11370 complete / 6303
# 11371 complete / 6303
# 11375 complete / 6303
# 11380 complete / 6303
# 11397 complete / 6303
# 11398 complete / 6303
# 11400 complete / 6303
# 11401 complete / 6303
# 11404 complete / 6303
# 11413 complete / 6303
# 11420 complete / 6303
# 11421 complete / 6303
# error on 11423: []
# 11423 complete / 6303
# 11427 complete / 6303
# 11429 complete / 6303
# 11430 complete / 6303
# 11431 complete / 6303
# 11439 complete / 6303
# 11442 complete / 6303
# 11444 complete / 6303
# 11451 complete / 6303
# 11452 complete / 6303
# 11453 complete / 6303
# 11456 complete / 6303
# 11457 complete / 6303
# 11459 complete / 6303
# 11460 complete / 6303
# 11467 complete / 6303
# 11468 complete / 6303
# 11469 complete / 6303
# 11470 complete / 6303
# 11478 complete / 6303
# 11499 complete / 6303
# 11515 complete / 6303
# 11518 complete / 6303
# 11523 complete / 6303
# 11529 complete / 6303
# 11531 complete / 6303
# 11535 complete / 6303
# 11540 complete / 6303
# 11544 complete / 6303
# 11547 complete / 6303
# 11559 complete / 6303
# 11560 complete / 6303
# 11565 complete / 6303
# 11600 complete / 6303
# 11615 complete / 6303
# 11619 complete / 6303
# 11631 complete / 6303
# 11635 complete / 6303
# 11636 complete / 6303
# 11637 complete / 6303
# 11638 complete / 6303
# 11647 complete / 6303
# 11648 complete / 6303
# 11652 complete / 6303
# 11653 complete / 6303
# 11658 complete / 6303
# 11659 complete / 6303
# 11661 complete / 6303
# 11662 complete / 6303
# 11665 complete / 6303
# 11678 complete / 6303
# 11679 complete / 6303
# 11683 complete / 6303
# 11688 complete / 6303
# 11692 complete / 6303
# 11699 complete / 6303
# 11761 complete / 6303
# 11770 complete / 6303
# 11774 complete / 6303
# 11775 complete / 6303
# 11802 complete / 6303
# 11804 complete / 6303
# 11807 complete / 6303
# 11812 complete / 6303
# 11817 complete / 6303
# 11820 complete / 6303
# 11826 complete / 6303
# 11835 complete / 6303
# 11836 complete / 6303
# 11838 complete / 6303
# 11845 complete / 6303
# 11849 complete / 6303
# 11852 complete / 6303
# 11857 complete / 6303
# 11866 complete / 6303
# 11870 complete / 6303
# 11880 complete / 6303
# 11887 complete / 6303
# 11888 complete / 6303
# 11889 complete / 6303
# 11891 complete / 6303
# 11892 complete / 6303
# 11908 complete / 6303
# 11910 complete / 6303
# 11917 complete / 6303
# 11918 complete / 6303
# 11928 complete / 6303
# 11931 complete / 6303
# 11968 complete / 6303
# 11973 complete / 6303
# 11978 complete / 6303
# 11979 complete / 6303
# 11983 complete / 6303
# 12079 complete / 6303
# 12085 complete / 6303
# 12090 complete / 6303
# 12093 complete / 6303
# 12094 complete / 6303
# 12096 complete / 6303
# 12100 complete / 6303
# 12103 complete / 6303
# 12107 complete / 6303
# 12109 complete / 6303
# 12113 complete / 6303
# 12133 complete / 6303
# 12138 complete / 6303
# 12140 complete / 6303
# 12142 complete / 6303
# 12146 complete / 6303
# 12149 complete / 6303
# 12153 complete / 6303
# 12155 complete / 6303
# 12162 complete / 6303
# 12163 complete / 6303
# 12171 complete / 6303
# 12177 complete / 6303
# 12178 complete / 6303
# 12180 complete / 6303
# 12182 complete / 6303
# 12184 complete / 6303
# 12192 complete / 6303
# 12193 complete / 6303
# 12201 complete / 6303
# 12205 complete / 6303
# 12211 complete / 6303
# 12212 complete / 6303
# 12222 complete / 6303
# 12225 complete / 6303
# 12242 complete / 6303
# 12244 complete / 6303
# 12246 complete / 6303
# 12253 complete / 6303
# 12271 complete / 6303
# 12277 complete / 6303
# 12279 complete / 6303
# 12289 complete / 6303
# 12308 complete / 6303
# 12312 complete / 6303
# 12400 complete / 6303
# 12403 complete / 6303
# 12404 complete / 6303
# 12405 complete / 6303
# 12412 complete / 6303
# 12429 complete / 6303
# 12435 complete / 6303
# 12437 complete / 6303
# 12444 complete / 6303
# 12445 complete / 6303
# 12448 complete / 6303
# 12473 complete / 6303
# 12483 complete / 6303
# 12484 complete / 6303
# error on 12490: []
# 12490 complete / 6303
# 12496 complete / 6303
# 12508 complete / 6303
# 12509 complete / 6303
# 12526 complete / 6303
# 12536 complete / 6303
# 12542 complete / 6303
# 12556 complete / 6303
# 12569 complete / 6303
# 12572 complete / 6303
# 12573 complete / 6303
# 12577 complete / 6303
# 12589 complete / 6303
# 12590 complete / 6303
# 12597 complete / 6303
# 12600 complete / 6303
# 12610 complete / 6303
# 12619 complete / 6303
# 12620 complete / 6303
# 12621 complete / 6303
# 12634 complete / 6303
# 12636 complete / 6303
# 12645 complete / 6303
# 12657 complete / 6303
# 12658 complete / 6303
# 12660 complete / 6303
# 12685 complete / 6303
# 12689 complete / 6303
# 12690 complete / 6303
# 12698 complete / 6303
# 12699 complete / 6303
# 12700 complete / 6303
# 12703 complete / 6303
# 12763 complete / 6303
# 12767 complete / 6303
# 12770 complete / 6303
# 12771 complete / 6303
# 12783 complete / 6303
# 12797 complete / 6303
# 12819 complete / 6303
# 12837 complete / 6303
# 12877 complete / 6303
# 12889 complete / 6303
# 12890 complete / 6303
# 12902 complete / 6303
# 12903 complete / 6303
# 12912 complete / 6303
# 12914 complete / 6303
# error on 12924: []
# 12924 complete / 6303
# 12994 complete / 6303
# 13001 complete / 6303
# 13002 complete / 6303
# 13004 complete / 6303
# 13007 complete / 6303
# 13008 complete / 6303
# 13009 complete / 6303
# 13012 complete / 6303
# 13015 complete / 6303
# 13016 complete / 6303
# 13018 complete / 6303
# 13019 complete / 6303
# 13022 complete / 6303
# 13025 complete / 6303
# 13027 complete / 6303
# 13042 complete / 6303
# 13043 complete / 6303
# 13051 complete / 6303
# 13053 complete / 6303
# 13054 complete / 6303
# 13056 complete / 6303
# 13059 complete / 6303
# 13060 complete / 6303
# 13061 complete / 6303
# 13062 complete / 6303
# 13068 complete / 6303
# 13073 complete / 6303
# 13074 complete / 6303
# 13075 complete / 6303
# 13078 complete / 6303
# 13079 complete / 6303
# 13090 complete / 6303
# 13092 complete / 6303
# 13094 complete / 6303
# 13107 complete / 6303
# 13121 complete / 6303
# 13127 complete / 6303
# 13141 complete / 6303
# 13150 complete / 6303
# 13156 complete / 6303
# 13159 complete / 6303
# 13160 complete / 6303
# 13161 complete / 6303
# 13166 complete / 6303
# 13168 complete / 6303
# 13171 complete / 6303
# 13172 complete / 6303
# 13177 complete / 6303
# 13179 complete / 6303
# 13180 complete / 6303
# 13183 complete / 6303
# 13184 complete / 6303
# error on 13185: []
# 13185 complete / 6303
# 13186 complete / 6303
# 13190 complete / 6303
# 13193 complete / 6303
# 13196 complete / 6303
# 13198 complete / 6303
# 13205 complete / 6303
# 13207 complete / 6303
# 13220 complete / 6303
# 13223 complete / 6303
# 13249 complete / 6303
# 13250 complete / 6303
# 13252 complete / 6303
# 13253 complete / 6303
# 13256 complete / 6303
# 13257 complete / 6303
# 13260 complete / 6303
# 13275 complete / 6303
# 13279 complete / 6303
# 13283 complete / 6303
# 13285 complete / 6303
# 13291 complete / 6303
# 13300 complete / 6303
# 13310 complete / 6303
# 13312 complete / 6303
# 13335 complete / 6303
# 13341 complete / 6303
# 13354 complete / 6303
# 13355 complete / 6303
# 13358 complete / 6303
# 13360 complete / 6303
# 13362 complete / 6303
# 13363 complete / 6303
# 13369 complete / 6303
# 13370 complete / 6303
# 13374 complete / 6303
# 13376 complete / 6303
# 13378 complete / 6303
# 13387 complete / 6303
# 13389 complete / 6303
# 13391 complete / 6303
# 13394 complete / 6303
# 13398 complete / 6303
# 13401 complete / 6303
# 13403 complete / 6303
# 13408 complete / 6303
# 13411 complete / 6303
# 13413 complete / 6303
# 13416 complete / 6303
# 13417 complete / 6303
# 13429 complete / 6303
# 13435 complete / 6303
# 13437 complete / 6303
# 13440 complete / 6303
# 13441 complete / 6303
# 13448 complete / 6303
# 13455 complete / 6303
# 13459 complete / 6303
# 13460 complete / 6303
# 13461 complete / 6303
# 13470 complete / 6303
# 13474 complete / 6303
# 13475 complete / 6303
# 13476 complete / 6303
# 13477 complete / 6303
# 13483 complete / 6303
# 13484 complete / 6303
# 13486 complete / 6303
# 13489 complete / 6303
# 13490 complete / 6303
# 13491 complete / 6303
# 13492 complete / 6303
# 13493 complete / 6303
# 13496 complete / 6303
# 13497 complete / 6303
# 13498 complete / 6303
# 13499 complete / 6303
# 13501 complete / 6303
# 13505 complete / 6303
# 13508 complete / 6303
# 13510 complete / 6303
# 13515 complete / 6303
# 13523 complete / 6303
# 13526 complete / 6303
# 13532 complete / 6303
# 13534 complete / 6303
# 13536 complete / 6303
# 13539 complete / 6303
# 13548 complete / 6303
# 13551 complete / 6303
# 13557 complete / 6303
# 13564 complete / 6303
# 13569 complete / 6303
# 13572 complete / 6303
# 13573 complete / 6303
# 13576 complete / 6303
# 13596 complete / 6303
# 13600 complete / 6303
# 13613 complete / 6303
# 13635 complete / 6303
# 13640 complete / 6303
# 13641 complete / 6303
# 13647 complete / 6303
# 13648 complete / 6303
# 13649 complete / 6303
# 13654 complete / 6303
# 13655 complete / 6303
# 13668 complete / 6303
# 13673 complete / 6303
# 13680 complete / 6303
# 13682 complete / 6303
# 13683 complete / 6303
# 13689 complete / 6303
# 13690 complete / 6303
# 13691 complete / 6303
# 13700 complete / 6303
# 13702 complete / 6303
# 13706 complete / 6303
# 13727 complete / 6303
# error on 13728: []
# 13728 complete / 6303
# 13751 complete / 6303
# 13754 complete / 6303
# 13767 complete / 6303
# 13768 complete / 6303
# 13778 complete / 6303
# 13785 complete / 6303
# 13788 complete / 6303
# 13797 complete / 6303
# 13803 complete / 6303
# 13805 complete / 6303
# 13807 complete / 6303
# 13809 complete / 6303
# 13811 complete / 6303
# 13812 complete / 6303
# 13813 complete / 6303
# 13819 complete / 6303
# 13830 complete / 6303
# 13836 complete / 6303
# 13848 complete / 6303
# 13849 complete / 6303
# 13851 complete / 6303
# 13855 complete / 6303
# 13885 complete / 6303
# 13908 complete / 6303
# 13919 complete / 6303
# 13922 complete / 6303
# 13930 complete / 6303
# 13931 complete / 6303
# 13932 complete / 6303
# 13933 complete / 6303
# 13934 complete / 6303
# 13944 complete / 6303
# 13949 complete / 6303
# 13950 complete / 6303
# 13954 complete / 6303
# 13955 complete / 6303
# 13956 complete / 6303
# 13958 complete / 6303
# error on 13964: []
# 13964 complete / 6303
# 13967 complete / 6303
# 13968 complete / 6303
# 13969 complete / 6303
# error on 13971: []
# 13971 complete / 6303
# 13972 complete / 6303
# 13973 complete / 6303
# 13975 complete / 6303
# 13980 complete / 6303
# 13981 complete / 6303
# 13988 complete / 6303
# 13991 complete / 6303
# 13994 complete / 6303
# 13996 complete / 6303
# 13998 complete / 6303
# 14000 complete / 6303
# 14001 complete / 6303
# 14003 complete / 6303
# 14008 complete / 6303
# 14011 complete / 6303
# 14012 complete / 6303
# error on 14016: []
# 14016 complete / 6303
# 14024 complete / 6303
# 14028 complete / 6303
# 14033 complete / 6303
# 14034 complete / 6303
# 14043 complete / 6303
# 14044 complete / 6303
# 14047 complete / 6303
# 14048 complete / 6303
# 14050 complete / 6303
# 14054 complete / 6303
# 14059 complete / 6303
# 14061 complete / 6303
# 14062 complete / 6303
# 14069 complete / 6303
# 14072 complete / 6303
# 14075 complete / 6303
# 14092 complete / 6303
# 14097 complete / 6303
# 14098 complete / 6303
# 14112 complete / 6303
# 14113 complete / 6303
# 14114 complete / 6303
# 14118 complete / 6303
# 14123 complete / 6303
# 14125 complete / 6303
# 14128 complete / 6303
# 14138 complete / 6303
# 14139 complete / 6303
# 14141 complete / 6303
# 14144 complete / 6303
# 14148 complete / 6303
# 14156 complete / 6303
# 14158 complete / 6303
# 14160 complete / 6303
# 14161 complete / 6303
# 14163 complete / 6303
# 14164 complete / 6303
# 14167 complete / 6303
# 14172 complete / 6303
# 14174 complete / 6303
# 14175 complete / 6303
# 14177 complete / 6303
# 14180 complete / 6303
# 14181 complete / 6303
# 14191 complete / 6303
# 14194 complete / 6303
# 14195 complete / 6303
# 14197 complete / 6303
# 14199 complete / 6303
# 14202 complete / 6303
# 14207 complete / 6303
# 14208 complete / 6303
# 14211 complete / 6303
# 14219 complete / 6303
# 14220 complete / 6303
# 14223 complete / 6303
# 14247 complete / 6303
# 14248 complete / 6303
# 14254 complete / 6303
# 14286 complete / 6303
# 14290 complete / 6303
# 14295 complete / 6303
# error on 14297: []
# 14297 complete / 6303
# 14299 complete / 6303
# 14306 complete / 6303
# 14310 complete / 6303
# 14313 complete / 6303
# 14324 complete / 6303
# 14325 complete / 6303
# 14326 complete / 6303
# 14337 complete / 6303
# 14348 complete / 6303
# 14353 complete / 6303
# 14358 complete / 6303
# 14359 complete / 6303
# 14365 complete / 6303
# 14369 complete / 6303
# 14375 complete / 6303
# 14392 complete / 6303
# 14396 complete / 6303
# 14397 complete / 6303
# 14400 complete / 6303
# 14405 complete / 6303
# 14410 complete / 6303
# 14411 complete / 6303
# 14423 complete / 6303
# 14424 complete / 6303
# 14434 complete / 6303
# 14435 complete / 6303
# 14438 complete / 6303
# 14442 complete / 6303
# 14447 complete / 6303
# 14457 complete / 6303
# 14458 complete / 6303
# 14462 complete / 6303
# 14517 complete / 6303
# 14527 complete / 6303
# 14536 complete / 6303
# 14538 complete / 6303
# 14544 complete / 6303
# 14547 complete / 6303
# 14549 complete / 6303
# 14556 complete / 6303
# 14560 complete / 6303
# 14564 complete / 6303
# 14574 complete / 6303
# 14576 complete / 6303
# 14582 complete / 6303
# 14609 complete / 6303
# 14611 complete / 6303
# 14613 complete / 6303
# 14620 complete / 6303
# 14623 complete / 6303
# 14624 complete / 6303
# 14629 complete / 6303
# 14635 complete / 6303
# 14636 complete / 6303
# 14637 complete / 6303
# 14643 complete / 6303
# 14655 complete / 6303
# 14686 complete / 6303
# 14695 complete / 6303
# 14711 complete / 6303
# 14728 complete / 6303
# 14736 complete / 6303
# 14749 complete / 6303
# 14753 complete / 6303
# 14756 complete / 6303
# 14761 complete / 6303
# 14784 complete / 6303
# 14787 complete / 6303
# 14799 complete / 6303
# 14805 complete / 6303
# 14830 complete / 6303
# 14836 complete / 6303
# 14843 complete / 6303
# 14844 complete / 6303
# 14845 complete / 6303
# 14846 complete / 6303
# 14849 complete / 6303
# 14851 complete / 6303
# 14857 complete / 6303
# 14859 complete / 6303
# 14863 complete / 6303
# 14869 complete / 6303
# 14871 complete / 6303
# 14872 complete / 6303
# 14873 complete / 6303
# 14874 complete / 6303
# 14882 complete / 6303
# 14912 complete / 6303
# 14913 complete / 6303
# 14914 complete / 6303
# 14926 complete / 6303
# 14933 complete / 6303
# 14938 complete / 6303
# 14940 complete / 6303
# 14943 complete / 6303
# 14976 complete / 6303
# 14977 complete / 6303
# 14979 complete / 6303
# 15003 complete / 6303
# 15004 complete / 6303
# 15005 complete / 6303
# 15015 complete / 6303
# 15016 complete / 6303
# 15017 complete / 6303
# 15019 complete / 6303
# 15022 complete / 6303
# 15028 complete / 6303
# 15039 complete / 6303
# 15045 complete / 6303
# 15049 complete / 6303
# 15058 complete / 6303
# 15060 complete / 6303
# 15067 complete / 6303
# 15069 complete / 6303
# 15070 complete / 6303
# 15071 complete / 6303
# 15088 complete / 6303
# 15092 complete / 6303
# 15135 complete / 6303
# error on 15136: []
# 15136 complete / 6303
# 15137 complete / 6303
# 15152 complete / 6303
# 15157 complete / 6303
# 15159 complete / 6303
# 15163 complete / 6303
# 15165 complete / 6303
# 15166 complete / 6303
# 15167 complete / 6303
# 15173 complete / 6303
# 15189 complete / 6303
# 15192 complete / 6303
# 15199 complete / 6303
# 15212 complete / 6303
# 15213 complete / 6303
# 15237 complete / 6303
# 15255 complete / 6303
# 15258 complete / 6303
# 15262 complete / 6303
# 15268 complete / 6303
# 15276 complete / 6303
# 15302 complete / 6303
# 15314 complete / 6303
# 15338 complete / 6303
# 15356 complete / 6303
# 15357 complete / 6303
# 15359 complete / 6303
# 15362 complete / 6303
# 15363 complete / 6303
# 15370 complete / 6303
# 15373 complete / 6303
# 15384 complete / 6303
# 15397 complete / 6303
# 15402 complete / 6303
# 15403 complete / 6303
# 15472 complete / 6303
# 15476 complete / 6303
# 15483 complete / 6303
# 15487 complete / 6303
# 15489 complete / 6303
# 15495 complete / 6303
# 15503 complete / 6303
# 15512 complete / 6303
# 15543 complete / 6303
# 15544 complete / 6303
# 15557 complete / 6303
# 15566 complete / 6303
# 15567 complete / 6303
# 15575 complete / 6303
# 15577 complete / 6303
# 15584 complete / 6303
# 15588 complete / 6303
# 15590 complete / 6303
# 15601 complete / 6303
# 15616 complete / 6303
# 15624 complete / 6303
# 15641 complete / 6303
# 15644 complete / 6303
# 15647 complete / 6303
# 15648 complete / 6303
# 15653 complete / 6303
# 15655 complete / 6303
# 15657 complete / 6303
# 15664 complete / 6303
# 15670 complete / 6303
# 15671 complete / 6303
# 15673 complete / 6303
# 15681 complete / 6303
# 15705 complete / 6303
# 15708 complete / 6303
# 15723 complete / 6303
# 15745 complete / 6303
# 15767 complete / 6303
# 15774 complete / 6303
# 15775 complete / 6303
# 15801 complete / 6303
# 15809 complete / 6303
# 15846 complete / 6303
# 15854 complete / 6303
# 15877 complete / 6303
# 15906 complete / 6303
# 15910 complete / 6303
# 15917 complete / 6303
# 15992 complete / 6303
# 15999 complete / 6303
# 16000 complete / 6303
# 16028 complete / 6303
# 16070 complete / 6303
# 16071 complete / 6303
# 16072 complete / 6303
# 16077 complete / 6303
# 16083 complete / 6303
# 16119 complete / 6303
# 16131 complete / 6303
# 16133 complete / 6303
# 16140 complete / 6303
# 16161 complete / 6303
# 16164 complete / 6303
# 16167 complete / 6303
# 16187 complete / 6303
# 16205 complete / 6303
# 16222 complete / 6303
# 16225 complete / 6303
# 16229 complete / 6303
# 16232 complete / 6303
# 16234 complete / 6303
# 16237 complete / 6303
# 16250 complete / 6303
# 16258 complete / 6303
# 16261 complete / 6303
# 16279 complete / 6303
# 16290 complete / 6303
# 16300 complete / 6303
# 16304 complete / 6303
# 16320 complete / 6303
# 16325 complete / 6303
# 16335 complete / 6303
# 16340 complete / 6303
# 16342 complete / 6303
# 16345 complete / 6303
# 16346 complete / 6303
# 16353 complete / 6303
# 16366 complete / 6303
# 16367 complete / 6303
# 16394 complete / 6303
# 16418 complete / 6303
# 16450 complete / 6303
# 16455 complete / 6303
# 16456 complete / 6303
# 16523 complete / 6303
# 16538 complete / 6303
# 16550 complete / 6303
# 16553 complete / 6303
# 16558 complete / 6303
# 16577 complete / 6303
# 16608 complete / 6303
# 16614 complete / 6303
# 16617 complete / 6303
# 16643 complete / 6303
# 16646 complete / 6303
# 16690 complete / 6303
# 16710 complete / 6303
# 16723 complete / 6303
# 16725 complete / 6303
# 16727 complete / 6303
# 16759 complete / 6303
# 16761 complete / 6303
# 16763 complete / 6303
# 16764 complete / 6303
# 16781 complete / 6303
# 16784 complete / 6303
# 16791 complete / 6303
# 16800 complete / 6303
# 16804 complete / 6303
# 16808 complete / 6303
# 16857 complete / 6303
# 16866 complete / 6303
# 16869 complete / 6303
# 16871 complete / 6303
# ...
# 524047 complete / 6303
# 524247 complete / 6303
# 524251 complete / 6303
# 524288 complete / 6303
# 524348 complete / 6303
# 524659 complete / 6303
# error on 524736: []
# 524736 complete / 6303
# 524738 complete / 6303
# 525041 complete / 6303
# 525183 complete / 6303
# 525428 complete / 6303
# 525460 complete / 6303
# 525554 complete / 6303
# 525657 complete / 6303
# 525661 complete / 6303
# 525814 complete / 6303
# 525903 complete / 6303
# 525946 complete / 6303
# 526007 complete / 6303
# 526019 complete / 6303
# 526050 complete / 6303
# 526051 complete / 6303
# 526120 complete / 6303
# 526511 complete / 6303
# error on 526746: []
# 526746 complete / 6303
# error on 526973: []
# 526973 complete / 6303
# error on 527246: []
# 527246 complete / 6303
# 527261 complete / 6303
# 527382 complete / 6303
# 527385 complete / 6303
# 527435 complete / 6303
# 527641 complete / 6303
# 527729 complete / 6303
# 527776 complete / 6303
# error on 527865: []
# 527865 complete / 6303
# 528491 complete / 6303
# error on 528668: []
# 528668 complete / 6303
# 528888 complete / 6303
# 528949 complete / 6303
# 528985 complete / 6303
# 529149 complete / 6303
# 529203 complete / 6303
# error on 529210: []
# 529210 complete / 6303
# 529216 complete / 6303
# 529485 complete / 6303
# 529531 complete / 6303
# 529784 complete / 6303
# 529862 complete / 6303
# 529962 complete / 6303
# 529983 complete / 6303
# 530076 complete / 6303
# 530081 complete / 6303
# 530157 complete / 6303
# error on 530254: []
# 530254 complete / 6303
# 530382 complete / 6303
# 530385 complete / 6303
# 530442 complete / 6303
# 530723 complete / 6303
# 530915 complete / 6303
# 530956 complete / 6303
# 531145 complete / 6303
# 531299 complete / 6303
# 531306 complete / 6303
# 531309 complete / 6303
# 531428 complete / 6303
# 531438 complete / 6303
# 531454 complete / 6303
# 531499 complete / 6303
# 531503 complete / 6303
# 531509 complete / 6303
# 531593 complete / 6303
# error on 531735: []
# 531735 complete / 6303
# 531736 complete / 6303
# 531876 complete / 6303
# 531949 complete / 6303
# error on 532067: []
# 532067 complete / 6303
# error on 532321: []
# 532321 complete / 6303
# error on 532620: []
# 532620 complete / 6303
# 532671 complete / 6303
# 532880 complete / 6303
# error on 532938: []
# 532938 complete / 6303
# 533444 complete / 6303
# 533642 complete / 6303
# 533715 complete / 6303
# error on 533992: []
# 533992 complete / 6303
# 534039 complete / 6303
# 534235 complete / 6303
# 534259 complete / 6303
# 534338 complete / 6303
# 534490 complete / 6303
# 534780 complete / 6303
# error on 534928: []
# 534928 complete / 6303
# error on 534939: []
# 534939 complete / 6303
# 535167 complete / 6303
# 535265 complete / 6303
# 535292 complete / 6303
# error on 535356: []
# 535356 complete / 6303
# 535389 complete / 6303
# 535437 complete / 6303
# 535544 complete / 6303
# 535581 complete / 6303
# 536115 complete / 6303
# 536176 complete / 6303
# error on 536506: []
# 536506 complete / 6303
# 536517 complete / 6303
# 536743 complete / 6303
# 536869 complete / 6303
# 537055 complete / 6303
# 537056 complete / 6303
# 537059 complete / 6303
# 537061 complete / 6303
# 537140 complete / 6303
# 537190 complete / 6303
# error on 537526: []
# 537526 complete / 6303
# 537617 complete / 6303
# 537681 complete / 6303
# 537739 complete / 6303
# 537788 complete / 6303
# 537915 complete / 6303
# 537996 complete / 6303
# 538002 complete / 6303
# 538225 complete / 6303
# 538362 complete / 6303
# 538604 complete / 6303
# 539199 complete / 6303
# 539517 complete / 6303
# error on 539531: []
# 539531 complete / 6303
# 539537 complete / 6303
# 539617 complete / 6303
# 539651 complete / 6303
# error on 539885: []
# 539885 complete / 6303
# 539892 complete / 6303
# 540158 complete / 6303
# 540247 complete / 6303
# 540709 complete / 6303
# 540901 complete / 6303
# 541099 complete / 6303
# 541305 complete / 6303
# error on 541340: []
# 541340 complete / 6303
# error on 541481: []
# 541481 complete / 6303
# error on 541483: []
# 541483 complete / 6303
# 541560 complete / 6303
# 541568 complete / 6303
# error on 541977: []
# 541977 complete / 6303
# 542224 complete / 6303
# 542417 complete / 6303
# error on 542830: []
# 542830 complete / 6303
# 542905 complete / 6303
# error on 542917: []
# 542917 complete / 6303
# error on 542921: []
# 542921 complete / 6303
# error on 542928: []
# 542928 complete / 6303
# error on 543103: []
# 543103 complete / 6303
# 543540 complete / 6303
# 543580 complete / 6303
# 544003 complete / 6303
# error on 544404: []
# 544404 complete / 6303
# 544431 complete / 6303
# 544510 complete / 6303
# 545237 complete / 6303
# 545609 complete / 6303
# 546554 complete / 6303
# 546724 complete / 6303
# 546726 complete / 6303
# 547016 complete / 6303
# 547017 complete / 6303
# error on 547388: []
# 547388 complete / 6303
# error on 547539: []
# 547539 complete / 6303
# 548066 complete / 6303
# error on 548170: []
# 548170 complete / 6303
# 548473 complete / 6303
# 548537 complete / 6303
# 548544 complete / 6303
# 548928 complete / 6303
# 549053 complete / 6303
# 549559 complete / 6303
# 550017 complete / 6303
# 550025 complete / 6303
# 550134 complete / 6303
# error on 550205: []
# 550205 complete / 6303
# 550385 complete / 6303
# 550440 complete / 6303
# error on 550738: []
# 550738 complete / 6303
# 550988 complete / 6303
# 551332 complete / 6303
# 551808 complete / 6303
# 551989 complete / 6303
# error on 552088: []
# 552088 complete / 6303
# 552095 complete / 6303
# 552178 complete / 6303
# 552670 complete / 6303
# 552865 complete / 6303
# 553141 complete / 6303
# 553539 complete / 6303
# 553600 complete / 6303
# error on 553608: []
# 553608 complete / 6303
# error on 553646: []
# 553646 complete / 6303
# 553798 complete / 6303
# error on 554133: []
# 554133 complete / 6303
# 554152 complete / 6303
# 554175 complete / 6303
# 554241 complete / 6303
# 554596 complete / 6303
# 554993 complete / 6303
# error on 555457: []
# 555457 complete / 6303
# error on 555561: []
# 555561 complete / 6303
# 555850 complete / 6303
# 555974 complete / 6303
# error on 556509: []
# 556509 complete / 6303
# 556574 complete / 6303
# 556678 complete / 6303
# 556803 complete / 6303
# 556901 complete / 6303
# 557336 complete / 6303
# 557635 complete / 6303
# 557968 complete / 6303
# 558198 complete / 6303
# 559302 complete / 6303
# error on 559401: []
# 559401 complete / 6303
# 559707 complete / 6303
# error on 559957: []
# 559957 complete / 6303
# 559969 complete / 6303
# 560044 complete / 6303
# 560050 complete / 6303
# 560066 complete / 6303
# 560192 complete / 6303
# 560204 complete / 6303
# 560362 complete / 6303
# 560391 complete / 6303
# 560704 complete / 6303
# 561325 complete / 6303
# error on 561557: []
# 561557 complete / 6303
# 561974 complete / 6303
# 563710 complete / 6303
# error on 563766: []
# 563766 complete / 6303
# 564147 complete / 6303
# 565028 complete / 6303
# error on 565156: []
# 565156 complete / 6303
# error on 565179: []
# 565179 complete / 6303
# 565214 complete / 6303
# 565276 complete / 6303
# 565310 complete / 6303
# 565312 complete / 6303
# 565348 complete / 6303
# error on 565413: []
# 565413 complete / 6303
# 565426 complete / 6303
# 565716 complete / 6303
# 565743 complete / 6303
# error on 566038: []
# 566038 complete / 6303
# 566213 complete / 6303
# 566221 complete / 6303
# 566222 complete / 6303
# 566228 complete / 6303
# 566367 complete / 6303
# 566368 complete / 6303
# 566454 complete / 6303
# error on 566675: []
# 566675 complete / 6303
# error on 566810: []
# 566810 complete / 6303
# 566949 complete / 6303
# error on 567227: []
# 567227 complete / 6303
# error on 567410: []
# 567410 complete / 6303
# 567598 complete / 6303
# 567604 complete / 6303
# 567608 complete / 6303
# 567609 complete / 6303
# 567629 complete / 6303
# error on 567646: []
# 567646 complete / 6303
# 567733 complete / 6303
# 567860 complete / 6303
# 567965 complete / 6303
# 567966 complete / 6303
# 567969 complete / 6303
# 567970 complete / 6303
# 567973 complete / 6303
# 568091 complete / 6303
# 568160 complete / 6303
# error on 568240: []
# 568240 complete / 6303
# 568332 complete / 6303
# 569547 complete / 6303
# error on 569715: []
# 569715 complete / 6303
# error on 569814: []
# 569814 complete / 6303
# 569982 complete / 6303
# error on 570131: []
# 570131 complete / 6303
# 570192 complete / 6303
# 570352 complete / 6303
# 570480 complete / 6303
# 570670 complete / 6303
# 570735 complete / 6303
# 571265 complete / 6303
# 571451 complete / 6303
# 571495 complete / 6303
# error on 571650: []
# 571650 complete / 6303
# error on 571655: []
# 571655 complete / 6303
# 571785 complete / 6303
# 571891 complete / 6303
# 572154 complete / 6303
# 572468 complete / 6303
# 573438 complete / 6303
# 574207 complete / 6303
# 574241 complete / 6303
# error on 574321: []
# 574321 complete / 6303
# 574370 complete / 6303
# 574376 complete / 6303
# error on 574434: []
# 574434 complete / 6303
# 574436 complete / 6303
# 574638 complete / 6303
# error on 574861: []
# 574861 complete / 6303
# 574982 complete / 6303
# 575094 complete / 6303
# 575190 complete / 6303
# 575236 complete / 6303
# error on 575299: []
# 575299 complete / 6303
# error on 575428: []
# 575428 complete / 6303
# 575452 complete / 6303
# error on 575730: []
# 575730 complete / 6303
# 575776 complete / 6303
# 575813 complete / 6303
# error on 575828: []
# 575828 complete / 6303
# 576017 complete / 6303
# 576040 complete / 6303
# 576156 complete / 6303
# 576379 complete / 6303
# 576712 complete / 6303
# error on 576953: []
# 576953 complete / 6303
# error on 577328: []
# 577328 complete / 6303
# 577922 complete / 6303
# error on 577990: []
# 577990 complete / 6303
# 578189 complete / 6303
# 578847 complete / 6303
# error on 579245: []
# 579245 complete / 6303
# 579450 complete / 6303
# 579583 complete / 6303
# 580001 complete / 6303
# 580489 complete / 6303
# error on 580600: []
# 580600 complete / 6303
# 580632 complete / 6303
# error on 581218: []
# 581218 complete / 6303
# error on 581387: []
# 581387 complete / 6303
# error on 581392: []
# 581392 complete / 6303
# 581420 complete / 6303
# 581475 complete / 6303
# error on 581528: []
# 581528 complete / 6303
# 581600 complete / 6303
# error on 581791: []
# 581791 complete / 6303
# 581859 complete / 6303
# 581997 complete / 6303
# 582186 complete / 6303
# error on 582206: []
# 582206 complete / 6303
# 582570 complete / 6303
# 582596 complete / 6303
# 582607 complete / 6303
# 582873 complete / 6303
# 582883 complete / 6303
# 582902 complete / 6303
# 582913 complete / 6303
# 582927 complete / 6303
# 583083 complete / 6303
# error on 583132: []
# 583132 complete / 6303
# error on 583268: []
# 583268 complete / 6303
# 583310 complete / 6303
# 583337 complete / 6303
# error on 583903: []
# 583903 complete / 6303
# 583984 complete / 6303
# error on 584427: []
# 584427 complete / 6303
# 584596 complete / 6303
# 584962 complete / 6303
# error on 585077: []
# 585077 complete / 6303
# 585244 complete / 6303
# 585311 complete / 6303
# 585530 complete / 6303
# error on 585759: []
# 585759 complete / 6303
# 585839 complete / 6303
# error on 586333: []
# 586333 complete / 6303
# 586347 complete / 6303
# 586451 complete / 6303
# 586461 complete / 6303
# 586592 complete / 6303
# 586863 complete / 6303
# 586940 complete / 6303
# 587138 complete / 6303
# 587301 complete / 6303
# 587496 complete / 6303
# 587693 complete / 6303
# 587808 complete / 6303
# error on 588001: []
# 588001 complete / 6303
# error on 588009: []
# 588009 complete / 6303
# 588226 complete / 6303
# 589049 complete / 6303
# 589739 complete / 6303
# error on 589982: []
# 589982 complete / 6303
# error on 590009: []
# 590009 complete / 6303
# 590123 complete / 6303
# 590164 complete / 6303
# 590575 complete / 6303
# error on 591121: []
# 591121 complete / 6303
# 591237 complete / 6303
# 591278 complete / 6303
# 591629 complete / 6303
# 591634 complete / 6303
# 591774 complete / 6303
# error on 592041: []
# 592041 complete / 6303
# 592350 complete / 6303
# error on 592480: []
# 592480 complete / 6303
# error on 592717: []
# 592717 complete / 6303
# 592834 complete / 6303
# 592863 complete / 6303
# 592867 complete / 6303
# error on 593035: []
# 593035 complete / 6303
# 593280 complete / 6303
# 593691 complete / 6303
# 594188 complete / 6303
# 594328 complete / 6303
# error on 594436: []
# 594436 complete / 6303
# 594530 complete / 6303
# error on 594634: []
# 594634 complete / 6303
# error on 594718: []
# 594718 complete / 6303
# 595148 complete / 6303
# 595215 complete / 6303
# 595671 complete / 6303
# 595841 complete / 6303
# error on 595867: []
# 595867 complete / 6303
# 595900 complete / 6303
# error on 595975: []
# 595975 complete / 6303
# 595985 complete / 6303
# error on 596054: []
# 596054 complete / 6303
# 597088 complete / 6303
# error on 597089: []
# 597089 complete / 6303
# 597219 complete / 6303
# 597233 complete / 6303
# 597594 complete / 6303
# 597722 complete / 6303
# 597965 complete / 6303
# 598133 complete / 6303
# 598215 complete / 6303
# 599281 complete / 6303
# 599521 complete / 6303
# error on 599845: []
# 599845 complete / 6303
# 599975 complete / 6303
# 600274 complete / 6303
# 600881 complete / 6303
# 601169 complete / 6303
# error on 601313: []
# 601313 complete / 6303
# 601844 complete / 6303
# error on 602063: []
# 602063 complete / 6303
# 602147 complete / 6303
# 602307 complete / 6303
# error on 602545: []
# 602545 complete / 6303
# 602609 complete / 6303
# 603519 complete / 6303
# 605373 complete / 6303
# error on 605734: []
# 605734 complete / 6303
# error on 605735: []
# 605735 complete / 6303
# 605804 complete / 6303
# 606117 complete / 6303
# 606679 complete / 6303
# 606856 complete / 6303
# error on 606954: []
# 606954 complete / 6303
# 607259 complete / 6303
# 607334 complete / 6303
# 607713 complete / 6303
# 608195 complete / 6303
# error on 608755: []
# 608755 complete / 6303
# error on 608826: []
# 608826 complete / 6303
# error on 609242: []
# 609242 complete / 6303
# 609338 complete / 6303
# error on 609760: []
# 609760 complete / 6303
# error on 609919: []
# 609919 complete / 6303
# error on 609956: []
# 609956 complete / 6303
# 610120 complete / 6303
# 610253 complete / 6303
# 610290 complete / 6303
# error on 610461: []
# 610461 complete / 6303
# error on 610643: []
# 610643 complete / 6303
# 610892 complete / 6303
# 611179 complete / 6303
# 611207 complete / 6303
# 611213 complete / 6303
# error on 611468: []
# 611468 complete / 6303
# 611562 complete / 6303
# 611605 complete / 6303
# 611761 complete / 6303
# 611914 complete / 6303
# 612152 complete / 6303
# error on 612368: []
# 612368 complete / 6303
# error on 612515: []
# 612515 complete / 6303
# error on 613090: []
# 613090 complete / 6303
# error on 613096: []
# 613096 complete / 6303
# error on 613099: []
# 613099 complete / 6303
# 613178 complete / 6303
# error on 613183: []
# 613183 complete / 6303
# error on 613504: []
# 613504 complete / 6303
# 613607 complete / 6303
# error on 613868: []
# 613868 complete / 6303
# 614167 complete / 6303
# error on 614206: []
# 614206 complete / 6303
# error on 614488: []
# 614488 complete / 6303
# error on 614587: []
# 614587 complete / 6303
# error on 614626: []
# 614626 complete / 6303
# 614715 complete / 6303
# 615177 complete / 6303
# 615453 complete / 6303
# 615774 complete / 6303
# 615790 complete / 6303
# 616037 complete / 6303
# 616584 complete / 6303
# error on 616803: []
# 616803 complete / 6303
# 617653 complete / 6303
# 617784 complete / 6303
# 617786 complete / 6303
# 618019 complete / 6303
# 618326 complete / 6303
# 618344 complete / 6303
# 618355 complete / 6303
# 618433 complete / 6303
# 619264 complete / 6303
# 619278 complete / 6303
# error on 619441: []
# 619441 complete / 6303
# 619592 complete / 6303
# error on 619914: []
# 619914 complete / 6303
# error on 620683: []
# 620683 complete / 6303
# 620725 complete / 6303
# 620741 complete / 6303
# 620883 complete / 6303
# 620924 complete / 6303
# 621013 complete / 6303
# error on 621191: []
# 621191 complete / 6303
# error on 621300: []
# 621300 complete / 6303
# error on 621561: []
# 621561 complete / 6303
# 621757 complete / 6303
# 621870 complete / 6303
# 621880 complete / 6303
# 621937 complete / 6303
# 622855 complete / 6303
# 622952 complete / 6303
# 622963 complete / 6303
# 623195 complete / 6303
# error on 623266: []
# 623266 complete / 6303
# error on 623520: []
# 623520 complete / 6303
# 623627 complete / 6303
# error on 624060: []
# 624060 complete / 6303
# 624788 complete / 6303
# 624808 complete / 6303
# 624860 complete / 6303
# 624899 complete / 6303
# 624932 complete / 6303
# 624989 complete / 6303
# 625450 complete / 6303
# 625561 complete / 6303
# 625568 complete / 6303
# 626746 complete / 6303
# 626751 complete / 6303
# 627070 complete / 6303
# 627290 complete / 6303
# 627463 complete / 6303
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-bcbd3d66f76b> in <module>
#       8     }
#       9     resp = requests.get(url, params = url_params)
# ---> 10     res = resp.json()['results']
#      11     try:
#      12         MPAA[ind] = [x for x in res if x['iso_3166_1'] == 'US'][0]['release_dates'][0]['certification']
#
# KeyError: 'results'

# %%
# turning it to dataframe to join
MPAA_df = pd.DataFrame.from_dict(MPAA, orient = 'index', columns = ['MPAA'])

# %%
full_df = movie_df.join(MPAA_df, on = 'id')

# %% [markdown]
# Before merging other datasets, let's make some information consistent.

# %%
# make all title lower to match across database
full_df['title'] = full_df['title'].apply(lambda x: x.lower())

# add a year to match addition to movie title (in case of same titles)
full_df['year'] = full_df.release_date.apply(lambda x: x[0:4])
full_df['month'] = full_df.release_date.apply(lambda x: x[5:7])

# %% [markdown]
# Existing Bom_movie dataset has some information on studios, we'll add it just in case.

# %%
bom_gross = pd.read_csv('zippedData/bom.movie_gross.csv')
bom_gross['title'] = bom_gross['title'].apply(lambda x: x.lower())
len(bom_gross)
# Out:
# 3387

# %%
# change bom_gross year to character to match other db
bom_gross.year = bom_gross.year.apply(str)
bom_gross = bom_gross[['title', 'year', 'studio']]

# %%
full_df = full_df.merge(bom_gross, right_on = ["title", "year"], \
                        left_on = ["title", "year"], how = 'left')

# %% [markdown]
# TN movie_budgets dataset has more extensive budget and gross information. Let's add these information

# %%
tn_budget = pd.read_csv('zippedData/tn.movie_budgets.csv')
tn_budget.head()
len(tn_budget)
# Out:
# 5782

# %%
# make all title lower to match across database
tn_budget['movie'] = tn_budget['movie'].apply(lambda x: x.lower())
# just get year information to match
tn_budget['year'] = tn_budget.release_date.apply(lambda x: x[-4:])

# %%
# merge dataframes
full_df = full_df.merge(tn_budget, right_on = ["movie", "year"], \
                        left_on = ["title", "year"], how = 'left')

# %%
full_df.columns
# Out:
# Index(['popularity', 'vote_count', 'id_x', 'adult', 'original_language',
#        'title', 'vote_average', 'overview', 'release_date_x', 'MPAA', 'year',
#        'month', 'studio', 'id_y', 'release_date_y', 'movie',
#        'production_budget', 'domestic_gross', 'worldwide_gross'],
#       dtype='object')

# %%
# let's drop some leftover columns
full_df.drop(['release_date_x', 'release_date_y','id_y', 'movie'], axis = 1, inplace = True)

# %%
len(full_df)
# Out:
# 8017

# %% [markdown]
# #### IMDB
# Let's pull some more information from IMDB

# %%
# Loading IMDB datasets
imdb_dat = pd.read_csv('zippedData/imdb.title.basics.csv')
imdb_rating = pd.read_csv('zippedData/imdb.title.ratings.csv')
imdb_crew = pd.read_csv('zippedData/imdb.title.crew.csv')

# %%
# let's  filter down imdb_dat to match movies in full_df and merge. 
# We will prioritize IMDB information as we need the in depth info from IMDB


imdb_dat['primary_title'] = imdb_dat['primary_title'].apply(lambda x: x.lower())
imdb_dat['start_year'] = imdb_dat['start_year'].apply(lambda x: str(x))

full_df = full_df.merge(imdb_dat, right_on = ["primary_title", "start_year"], \
                        left_on = ["title", "year"])

# %%
len(full_df)
# Out:
# 3878

# %% [markdown]
# #### IMDB Rating
# Adding IMDB rating information

# %%
full_df = full_df.merge(imdb_rating, on = ['tconst'])
full_df.rename(columns={"averagerating": "avg_rating_imdb", "numvotes": "num_votes_imdb"}, inplace = True)

# %% [markdown]
# #### Directors & Writers
# IMDB has info on directors and writers but they are in name codes
# I'll find the matching name from people database so we can understand who's who.

# %%
# match imdb name codes for directors and writers to their actual names
imdb_people = pd.read_csv('zippedData/imdb.name.basics.csv')
pep_names = imdb_people.iloc[:, 0:2]

# %%
imdb_prin = pd.read_csv('zippedData/imdb.title.principals.csv')

# %%
# merge nconst to get actual names
imdb_prin_sub = imdb_prin.merge(pep_names, on = 'nconst')
imdb_prin_sub = imdb_prin_sub[['tconst', 'primary_name', 'category']]

# %%
actors = imdb_prin_sub[(imdb_prin_sub.category == 'actress') | (imdb_prin_sub.category == 'actor')][['tconst', 'primary_name']]
directors = imdb_prin_sub[imdb_prin_sub.category == 'director'][['tconst', 'primary_name']]
producers = imdb_prin_sub[imdb_prin_sub.category == 'producer'][['tconst', 'primary_name']]
editors = imdb_prin_sub[imdb_prin_sub.category == 'editor'][['tconst', 'primary_name']]
writers = imdb_prin_sub[imdb_prin_sub.category == 'writer'][['tconst', 'primary_name']]

# %% [markdown]
# LEVEL UP: If I have time - see if below can be done more elegantly using pivoting

# %%
actors = actors.groupby('tconst').primary_name.apply(lambda x: ','.join(x)).reset_index()
directors = directors.groupby('tconst').primary_name.apply(lambda x: ','.join(x)).reset_index()
producers = producers.groupby('tconst').primary_name.apply(lambda x: ','.join(x)).reset_index()
editors = editors.groupby('tconst').primary_name.apply(lambda x: ','.join(x)).reset_index()
writers = writers.groupby('tconst').primary_name.apply(lambda x: ','.join(x)).reset_index()

# %%
# merge
full_df = full_df.merge(actors, on = 'tconst', how = 'left')
full_df.rename(columns = {'primary_name':'actors'}, inplace = True)
full_df = full_df.merge(directors, on = 'tconst', how = 'left')
full_df.rename(columns = {'primary_name':'directors'}, inplace = True)
full_df = full_df.merge(producers, on = 'tconst', how = 'left')
full_df.rename(columns = {'primary_name':'producers'}, inplace = True)
full_df = full_df.merge(editors, on = 'tconst', how = 'left')
full_df.rename(columns = {'primary_name':'editors'}, inplace = True)
full_df = full_df.merge(writers, on = 'tconst', how = 'left')
full_df.rename(columns = {'primary_name':'writers'}, inplace = True)

# %% [markdown]
# ## COCO 2017
# There were 2 movies named Coco in 2017. This messes up the data since we have used year + title as identifying information for some of the data merge. so we will remove the horror coco.

# %%
full_df.drop(2332, inplace = True)

# %% [markdown]
# ## Remove Duplicates
# Duplicates got in somehow, let's remove them

# %%
full_df.drop_duplicates(subset = 'id_x', inplace= True)

# %% [markdown]
# ## Cleaning up Genres

# %%
# add primary genre
full_df['primary_genre'] = full_df.genres.str.split(',', expand = True)[0]

# %%
full_df['secondary_genre'] = full_df.genres.str.split(',', expand = True)[1]

# %%
# function to call out animation as a separate genre
def newgen(x):
    if x.primary_genre == x.secondary_genre:
        return x.primary_genre
    if x.primary_genre == "Animation" or x.secondary_genre == "Animation":
        return "Animation"
    else:
        return x.primary_genre

# %%
full_df['new_genre'] = full_df.apply(newgen, axis = 1)

# %% [markdown]
# ## profit_df
# full_df contains all the information so far. Now I'll create sub-dataframes that keeps only budget/revenue information. If we run analyses that don't look at the budget/gross we can use full_df. Otherwise, we will use profit_df

# %%
# drop rows if any of the budget/gross information is missing
profit_df = full_df.dropna(axis = 0, 
                           subset = ['production_budget', 'domestic_gross', 'worldwide_gross'])

len(profit_df)
# Out:
# 1236

# %%
# some has '$0' as its gross, which probably means that this data is not yet available. 
# let's exclude them if it's missing .
profit_df = profit_df[(profit_df.domestic_gross != '$0')]

# %%
# Now convert these information as numbers and scale it as a million $.
profit_df.production_budget = profit_df.production_budget.apply(lambda x: round(int(x[1:].replace(',', ''))/1000000, 2))
profit_df.domestic_gross = profit_df.domestic_gross.apply(lambda x: round(int(x[1:].replace(',', ''))/1000000, 2))
profit_df.worldwide_gross = profit_df.worldwide_gross.apply(lambda x: round(int(x[1:].replace(',', ''))/1000000, 2))

# %%
## Normalize worldwide_gross / domestic_gross (since their scales different 
# and we want to compare the level of success.

profit_df['worldwide_gross_z'] = profit_df.worldwide_gross.apply(
    lambda x: (x-profit_df.worldwide_gross.mean())/(profit_df.worldwide_gross.std()))
profit_df['domestic_gross_z'] = profit_df.domestic_gross.apply(
    lambda x: (x-profit_df.domestic_gross.mean())/(profit_df.domestic_gross.std()))

# %%
len(profit_df)
# Out:
# 1193

# %%
profit_df.isnull().sum()
# Out:
# popularity              0
# vote_count              0
# id_x                    0
# adult                   0
# original_language       0
# title                   0
# vote_average            0
# overview                0
# MPAA                    1
# year                    0
# month                   0
# studio                192
# production_budget       0
# domestic_gross          0
# worldwide_gross         0
# tconst                  0
# primary_title           0
# original_title          0
# start_year              0
# runtime_minutes         0
# genres                  0
# avg_rating_imdb         0
# num_votes_imdb          0
# actors                  7
# directors              32
# producers             135
# editors              1048
# writers               170
# primary_genre           0
# secondary_genre        67
# new_genre               0
# worldwide_gross_z       0
# domestic_gross_z        0
# dtype: int64

# %% [markdown]
# These missing categorical values are not key factors for all analyses.
# We will remove them as we see fit for individual topics.

# %%
#Exporting here to do other things

import csv
full_df.to_csv('data/full_data.csv')
profit_df.to_csv('data/profit_data.csv')

# %% [markdown]
# # Non-superhero data
# Our data shows that last 10 years of movies have been highly influenced by superhero movies.
# But superhero movie market, dominated by big name studios, is a costly red ocean to break in.
# So we may want to look at the trend of film industry without these big name superhero films.
# We will exclude them by taking out films that had Jack Kirby, Stan Lee and Zak Penn as writers.

# %%
profit_df_no_sup = profit_df[~ profit_df.writers.apply(lambda x: 'Jack Kirby' in str(x))]
profit_df_no_sup = profit_df_no_sup[~ profit_df_no_sup.writers.apply(lambda x: 'Stan Lee' in str(x))]
profit_df_no_sup = profit_df_no_sup[~ profit_df_no_sup.writers.apply(lambda x: 'Zak Penn' in str(x))]

# %%
profit_df_no_sup.sort_values(['worldwide_gross'], ascending = False).head(3)
# Out:
#       popularity  vote_count    id_x  adult original_language  \
# 1043      29.590       15745  135397  False                en
# 1200      23.087        7612  168259  False                en
# 2290      43.033        7767  351286  False                en
#
#                                title  vote_average  \
# 1043                  jurassic world           6.6
# 1200                       furious 7           7.3
# 2290  jurassic world: fallen kingdom           6.5
#
#                                                overview   MPAA  year  ...  \
# 1043  Twenty-two years after the events of Jurassic ...  PG-13  2015  ...
# 1200  Deckard Shaw seeks revenge against Dominic Tor...  PG-13  2015  ...
# 2290  Three years after the demise of Jurassic World...         2018  ...
#
#                                                  actors        directors  \
# 1043  Chris Pratt,Bryce Dallas Howard,Ty Simpkins,Ju...  Colin Trevorrow
# 1200  Dwayne Johnson,Vin Diesel,Jason Statham,Paul W...        James Wan
# 2290  Rafe Spall,Chris Pratt,Bryce Dallas Howard,Jus...      J.A. Bayona
#
#                             producers  editors  \
# 1043                  Patrick Crowley      NaN
# 1200  Michael Fottrell,Neal H. Moritz      NaN
# 2290    Patrick Crowley,Belén Atienza      NaN
#
#                                                 writers primary_genre  \
# 1043  Rick Jaffa,Amanda Silver,Derek Connolly,Michae...        Action
# 1200                   Chris Morgan,Gary Scott Thompson        Action
# 2290    Colin Trevorrow,Derek Connolly,Michael Crichton        Action
#
#      secondary_genre new_genre worldwide_gross_z  domestic_gross_z
# 1043       Adventure    Action          5.960539          6.532597
# 1200           Crime    Action          5.434842          3.176849
# 2290       Adventure    Action          4.574571          3.902474
#
# [3 rows x 33 columns]

# %% [markdown]
# ### Reassigning z-values (normalizing in this new population)

# %%
## Normalize worldwide_gross / domestic_gross (since their scales different 
# and we want to compare the level of success.

profit_df_no_sup['worldwide_gross_z'] = profit_df_no_sup.worldwide_gross.apply(
    lambda x: (x-profit_df_no_sup.worldwide_gross.mean())/(profit_df_no_sup.worldwide_gross.std()))
profit_df_no_sup['domestic_gross_z'] = profit_df_no_sup.domestic_gross.apply(
    lambda x: (x-profit_df_no_sup.domestic_gross.mean())/(profit_df_no_sup.domestic_gross.std()))

# %%
profit_df_no_sup.columns
# Out:
# Index(['popularity', 'vote_count', 'id_x', 'adult', 'original_language',
#        'title', 'vote_average', 'overview', 'MPAA', 'year', 'month', 'studio',
#        'production_budget', 'domestic_gross', 'worldwide_gross', 'tconst',
#        'primary_title', 'original_title', 'start_year', 'runtime_minutes',
#        'genres', 'avg_rating_imdb', 'num_votes_imdb', 'actors', 'directors',
#        'producers', 'editors', 'writers', 'primary_genre', 'secondary_genre',
#        'new_genre', 'worldwide_gross_z', 'domestic_gross_z'],
#       dtype='object')

# %% [markdown]
# # Exporting

# %%
#Exporting a new dataframe
profit_df_no_sup.to_csv('data/profit_data_no_sup.csv')
